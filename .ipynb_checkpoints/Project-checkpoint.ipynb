# %%
import pandas as pd

# %% [markdown]
# # Inegi

# %%
inegi = pd.read_csv('inegi.csv')
inegi.drop(columns=['nom_estab', 'per_ocu', 'fecha_alta', 'nom_processed', 'tipoUniEco'], inplace=True)
inegi.columns
# Out:
# Index(['entidad', 'municipio', 'localidad', 'latitud', 'longitud', 'tipo',
#        'Cocina Económica', 'Antojitos', 'Pizza', 'Hamburguesas', 'Hot Dogs',
#        'Sushi', 'Tamales', 'Mariscos', 'Pescado', 'Tacos', 'Carne', 'Asada',
#        'Panuchos', 'Cochinita', 'Pollo', 'Desayunos', 'Tortas', 'Mondongo',
#        'Menudo', 'Memelas', 'Empanadas', 'Chicharrón', 'Gorditas', 'Costillas',
#        'Carnitas', 'Doraditas', 'Baguettes', 'Parrilla', 'Huaraches',
#        'Rosticería', 'China', 'Yucateca', 'Tabasqueña', 'Arrachera', 'Pastor',
#        'Birria', 'Barbacoa', 'Carnero', 'Pozole', 'Enchiladas', 'Chilaquiles'],
#       dtype='object')

# %%
inegi['entidad'] = inegi['entidad'].apply(lambda x: 'YUCATAN' if 'YUCA' in x else x)
yinegi = inegi[inegi['entidad']=='YUCATAN']
yinegi.head()
# Out:
#         entidad municipio localidad    latitud   longitud          tipo  \
# 152158  YUCATAN    Mérida    Mérida  21.001433 -89.605708  ['arracher']
# 152159  YUCATAN    Mérida    Mérida  21.038795 -89.601918            []
# 152160  YUCATAN    Mérida    Mérida  21.024276 -89.624382            []
# 152161  YUCATAN    Mérida    Mérida  21.020646 -89.585322   ['restaur']
# 152162  YUCATAN    Mérida    Mérida  20.998787 -89.566374      ['pizz']
#
#         Cocina Económica  Antojitos  Pizza  Hamburguesas  ...  Yucateca  \
# 152158                 0          0      0             0  ...         0
# 152159                 0          0      0             0  ...         0
# 152160                 0          0      0             0  ...         0
# 152161                 0          0      0             0  ...         0
# 152162                 0          0      1             0  ...         0
#
#         Tabasqueña  Arrachera  Pastor  Birria  Barbacoa  Carnero  Pozole  \
# 152158           0          1       0       0         0        0       0
# 152159           0          0       0       0         0        0       0
# 152160           0          0       0       0         0        0       0
# 152161           0          0       0       0         0        0       0
# 152162           0          0       0       0         0        0       0
#
#         Enchiladas  Chilaquiles
# 152158           0            0
# 152159           0            0
# 152160           0            0
# 152161           0            0
# 152162           0            0
#
# [5 rows x 47 columns]

# %%
yinegi['localidad'].value_counts()
# Out:
# Mérida                      7475
# Valladolid                   636
# Kanasín                      600
# Tizimín                      529
# Ticul                        483
#                             ...
# Hubikú                         1
# Misión [Hotel]                 1
# San Antonio Chablé             1
# San Francisco Manzanilla       1
# San Felipe Nuevo               1
# Name: localidad, Length: 157, dtype: int64

# %%
yinegi.drop(yinegi[yinegi['localidad']!='Mérida'].index, inplace=True)
yinegi['localidad'].value_counts()
# Out:
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# Mérida    7475
# Name: localidad, dtype: int64

# %%
foods = ['Cocina Económica', 'Antojitos', 'Pizza', 'Hamburguesas', 'Hot Dogs', 'Sushi', 'Tamales', 'Mariscos', 
         'Pescado', 'Tacos', 'Carne', 'Asada', 'Panuchos', 'Cochinita', 'Pollo', 'Desayunos', 'Tortas', 'Mondongo', 
         'Menudo', 'Memelas', 'Empanadas', 'Chicharrón', 'Gorditas', 'Costillas', 'Carnitas', 'Doraditas', 
         'Baguettes', 'Parrilla', 'Huaraches', 'Rosticería', 'China', 'Yucateca', 'Tabasqueña', 'Arrachera', 
         'Pastor', 'Birria', 'Barbacoa', 'Carnero', 'Pozole', 'Enchiladas', 'Chilaquiles']

# %%
inegi_results = {}

for food in foods:
    inegi_results[food] = yinegi[food].sum()
    
inegi_results
# Out:
# {'Cocina Económica': 1409,
#  'Antojitos': 1030,
#  'Pizza': 309,
#  'Hamburguesas': 149,
#  'Hot Dogs': 36,
#  'Sushi': 42,
#  'Tamales': 91,
#  'Mariscos': 59,
#  'Pescado': 91,
#  'Tacos': 670,
#  'Carne': 1,
#  'Asada': 177,
#  'Panuchos': 198,
#  'Cochinita': 118,
#  'Pollo': 230,
#  'Desayunos': 89,
#  'Tortas': 203,
#  'Mondongo': 13,
#  'Menudo': 0,
#  'Memelas': 0,
#  'Empanadas': 27,
#  'Chicharrón': 74,
#  'Gorditas': 10,
#  'Costillas': 15,
#  'Carnitas': 40,
#  'Doraditas': 23,
#  'Baguettes': 6,
#  'Parrilla': 43,
#  'Huaraches': 7,
#  'Rosticería': 20,
#  'China': 0,
#  'Yucateca': 48,
#  'Tabasqueña': 13,
#  'Arrachera': 4,
#  'Pastor': 22,
#  'Birria': 0,
#  'Barbacoa': 15,
#  'Carnero': 1,
#  'Pozole': 12,
#  'Enchiladas': 1,
#  'Chilaquiles': 0}

# %%
pd.set_option('display.max_rows', 20)

# %%
df = pd.DataFrame(inegi_results.items(), columns = ['Index', 'InegiCount']).set_index('Index')
df.head()
# Out:
#                   InegiCount
# Index
# Cocina Económica        1409
# Antojitos               1030
# Pizza                    309
# Hamburguesas             149
# Hot Dogs                  36

# %% [markdown]
# # Google Trends

# %% [markdown]
# ### Revisaremos qué tantas búsquedas se hacen en Google sobre cada uno de los giros de comida, con el fin de conocer dónde está el interés del consumidor.
# ### Para esto utilizaremos la API de Google Trends a través de pytrends.

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='es-MX', tz=360)

# %%
resultados = []
for comida in inegi_results:
    print(comida)
    pytrends.build_payload([comida], cat=71, geo='MX', gprop='')
    resultados.append(pytrends.interest_by_region(resolution='REGION', inc_low_vol=True, inc_geo_code=False))
    
resultados
# Out:
# Cocina Económica
# Antojitos
# Pizza
# Hamburguesas
# Hot Dogs
# Sushi
# Tamales
# Mariscos
# Pescado
# Tacos
# Carne
# Asada
# Panuchos
# Cochinita
# Pollo
# Desayunos
# Tortas
# Mondongo
# Menudo
# Memelas
# Empanadas
# Chicharrón
# Gorditas
# Costillas
# Carnitas
# Doraditas
# Baguettes
# Parrilla
# Huaraches
# Rosticería
# China
# Yucateca
# Tabasqueña
# Arrachera
# Pastor
# Birria
# Barbacoa
# Carnero
# Pozole
# Enchiladas
# Chilaquiles
# [                     Cocina Económica
#  geoName
#  Aguascalientes                      0
#  Baja California                     0
#  Baja California Sur                 0
#  Campeche                            0
#  Chiapas                             0
#  ...                               ...
#  Tamaulipas                          0
#  Tlaxcala                            0
#  Veracruz                            0
#  Yucatán                           100
#  Zacatecas                           0
#
#  [32 rows x 1 columns],                      Antojitos
#  geoName
#  Aguascalientes              12
#  Baja California             20
#  Baja California Sur         19
#  Campeche                   100
#  Chiapas                     30
#  ...                        ...
#  Tamaulipas                  25
#  Tlaxcala                    18
#  Veracruz                    58
#  Yucatán                     33
#  Zacatecas                   30
#
#  [32 rows x 1 columns],                      Pizza
#  geoName
#  Aguascalientes          71
#  Baja California         83
#  Baja California Sur     74
#  Campeche                77
#  Chiapas                 79
#  ...                    ...
#  Tamaulipas              62
#  Tlaxcala                39
#  Veracruz                64
#  Yucatán                100
#  Zacatecas               45
#
#  [32 rows x 1 columns],                      Hamburguesas
#  geoName
#  Aguascalientes                 71
#  Baja California                76
#  Baja California Sur            43
#  Campeche                       54
#  Chiapas                        44
#  ...                           ...
#  Tamaulipas                     62
#  Tlaxcala                       39
#  Veracruz                       60
#  Yucatán                        53
#  Zacatecas                      76
#
#  [32 rows x 1 columns],                      Hot Dogs
#  geoName
#  Aguascalientes             35
#  Baja California            90
#  Baja California Sur        73
#  Campeche                    0
#  Chiapas                    20
#  ...                       ...
#  Tamaulipas                 43
#  Tlaxcala                    0
#  Veracruz                   33
#  Yucatán                    28
#  Zacatecas                   0
#
#  [32 rows x 1 columns],                      Sushi
#  geoName
#  Aguascalientes          43
#  Baja California         46
#  Baja California Sur     52
#  Campeche                10
#  Chiapas                  8
#  ...                    ...
#  Tamaulipas               8
#  Tlaxcala                 7
#  Veracruz                 8
#  Yucatán                 30
#  Zacatecas               12
#
#  [32 rows x 1 columns],                      Tamales
#  geoName
#  Aguascalientes            64
#  Baja California           81
#  Baja California Sur       78
#  Campeche                  63
#  Chiapas                   41
#  ...                      ...
#  Tamaulipas               100
#  Tlaxcala                  53
#  Veracruz                  80
#  Yucatán                   55
#  Zacatecas                 60
#
#  [32 rows x 1 columns],                      Mariscos
#  geoName
#  Aguascalientes             33
#  Baja California            45
#  Baja California Sur        41
#  Campeche                   23
#  Chiapas                    19
#  ...                       ...
#  Tamaulipas                 42
#  Tlaxcala                   18
#  Veracruz                   24
#  Yucatán                    30
#  Zacatecas                  27
#
#  [32 rows x 1 columns],                      Pescado
#  geoName
#  Aguascalientes            62
#  Baja California           74
#  Baja California Sur      100
#  Campeche                  62
#  Chiapas                   46
#  ...                      ...
#  Tamaulipas                55
#  Tlaxcala                  40
#  Veracruz                  50
#  Yucatán                   56
#  Zacatecas                 55
#
#  [32 rows x 1 columns],                      Tacos
#  geoName
#  Aguascalientes          33
#  Baja California         35
#  Baja California Sur     33
#  Campeche                21
#  Chiapas                 24
#  ...                    ...
#  Tamaulipas              28
#  Tlaxcala                22
#  Veracruz                27
#  Yucatán                 22
#  Zacatecas               27
#
#  [32 rows x 1 columns],                      Carne
#  geoName
#  Aguascalientes          69
#  Baja California         73
#  Baja California Sur     83
#  Campeche                72
#  Chiapas                 61
#  ...                    ...
#  Tamaulipas              76
#  Tlaxcala                57
#  Veracruz                63
#  Yucatán                 64
#  Zacatecas               70
#
#  [32 rows x 1 columns],                      Asada
#  geoName
#  Aguascalientes          55
#  Baja California         66
#  Baja California Sur     75
#  Campeche                34
#  Chiapas                 45
#  ...                    ...
#  Tamaulipas              67
#  Tlaxcala                34
#  Veracruz                32
#  Yucatán                 38
#  Zacatecas               48
#
#  [32 rows x 1 columns],                      Panuchos
#  geoName
#  Aguascalientes              0
#  Baja California             7
#  Baja California Sur         0
#  Campeche                  100
#  Chiapas                    15
#  ...                       ...
#  Tamaulipas                 10
#  Tlaxcala                    0
#  Veracruz                   19
#  Yucatán                   100
#  Zacatecas                   0
#
#  [32 rows x 1 columns],                      Cochinita
#  geoName
#  Aguascalientes              44
#  Baja California             70
#  Baja California Sur         37
#  Campeche                    83
#  Chiapas                     40
#  ...                        ...
#  Tamaulipas                  42
#  Tlaxcala                    36
#  Veracruz                    68
#  Yucatán                     86
#  Zacatecas                   24
#
#  [32 rows x 1 columns],                      Pollo
#  geoName
#  Aguascalientes          52
#  Baja California         71
#  Baja California Sur     72
#  Campeche                85
#  Chiapas                 83
#  ...                    ...
#  Tamaulipas              85
#  Tlaxcala                50
#  Veracruz                71
#  Yucatán                 78
#  Zacatecas               52
#
#  [32 rows x 1 columns],                      Desayunos
#  geoName
#  Aguascalientes              60
#  Baja California             81
#  Baja California Sur         83
#  Campeche                    81
#  Chiapas                     90
#  ...                        ...
#  Tamaulipas                  50
#  Tlaxcala                    61
#  Veracruz                    70
#  Yucatán                     77
#  Zacatecas                   59
#
#  [32 rows x 1 columns],                      Tortas
#  geoName
#  Aguascalientes           25
#  Baja California          19
#  Baja California Sur      21
#  Campeche                 26
#  Chiapas                  12
#  ...                     ...
#  Tamaulipas               22
#  Tlaxcala                 17
#  Veracruz                 22
#  Yucatán                  22
#  Zacatecas                19
#
#  [32 rows x 1 columns],                      Mondongo
#  geoName
#  Aguascalientes              9
#  Baja California            10
#  Baja California Sur        10
#  Campeche                  100
#  Chiapas                    36
#  ...                       ...
#  Tamaulipas                 29
#  Tlaxcala                    0
#  Veracruz                   49
#  Yucatán                    80
#  Zacatecas                   0
#
#  [32 rows x 1 columns],                      Menudo
#  geoName
#  Aguascalientes           50
#  Baja California         100
#  Baja California Sur      65
#  Campeche                 10
#  Chiapas                  13
#  ...                     ...
#  Tamaulipas               74
#  Tlaxcala                 12
#  Veracruz                 14
#  Yucatán                  13
#  Zacatecas                53
#
#  [32 rows x 1 columns],                      Memelas
#  geoName
#  Aguascalientes            25
#  Baja California           22
#  Baja California Sur        0
#  Campeche                   0
#  Chiapas                    0
#  ...                      ...
#  Tamaulipas                20
#  Tlaxcala                   0
#  Veracruz                  69
#  Yucatán                   37
#  Zacatecas                  0
#
#  [32 rows x 1 columns],                      Empanadas
#  geoName
#  Aguascalientes              28
#  Baja California             37
#  Baja California Sur         59
#  Campeche                    40
#  Chiapas                     37
#  ...                        ...
#  Tamaulipas                  58
#  Tlaxcala                    19
#  Veracruz                    38
#  Yucatán                     37
#  Zacatecas                   34
#
#  [32 rows x 1 columns],                      Chicharrón
#  geoName
#  Aguascalientes               77
#  Baja California              41
#  Baja California Sur           0
#  Campeche                      0
#  Chiapas                      57
#  ...                         ...
#  Tamaulipas                   76
#  Tlaxcala                      0
#  Veracruz                     65
#  Yucatán                      76
#  Zacatecas                     0
#
#  [32 rows x 1 columns],                      Gorditas
#  geoName
#  Aguascalientes             44
#  Baja California            32
#  Baja California Sur        44
#  Campeche                   21
#  Chiapas                    25
#  ...                       ...
#  Tamaulipas                 79
#  Tlaxcala                   19
#  Veracruz                   23
#  Yucatán                    18
#  Zacatecas                  55
#
#  [32 rows x 1 columns],                      Costillas
#  geoName
#  Aguascalientes             100
#  Baja California             66
#  Baja California Sur         65
#  Campeche                    59
#  Chiapas                     61
#  ...                        ...
#  Tamaulipas                  57
#  Tlaxcala                    69
#  Veracruz                    61
#  Yucatán                     57
#  Zacatecas                   75
#
#  [32 rows x 1 columns],                      Carnitas
#  geoName
#  Aguascalientes             50
#  Baja California            48
#  Baja California Sur        51
#  Campeche                   50
#  Chiapas                    32
#  ...                       ...
#  Tamaulipas                 48
#  Tlaxcala                   29
#  Veracruz                   36
#  Yucatán                    47
#  Zacatecas                  38
#
#  [32 rows x 1 columns],                      Doraditas
#  geoName
#  Aguascalientes               0
#  Baja California             12
#  Baja California Sur          0
#  Campeche                     0
#  Chiapas                      0
#  ...                        ...
#  Tamaulipas                   0
#  Tlaxcala                     0
#  Veracruz                     9
#  Yucatán                    100
#  Zacatecas                    0
#
#  [32 rows x 1 columns],                      Baguettes
#  geoName
#  Aguascalientes               0
#  Baja California              0
#  Baja California Sur          0
#  Campeche                     0
#  Chiapas                      0
#  ...                        ...
#  Tamaulipas                   0
#  Tlaxcala                     0
#  Veracruz                    34
#  Yucatán                    100
#  Zacatecas                    0
#
#  [32 rows x 1 columns],                      Parrilla
#  geoName
#  Aguascalientes             15
#  Baja California            13
#  Baja California Sur        16
#  Campeche                   29
#  Chiapas                    50
#  ...                       ...
#  Tamaulipas                 17
#  Tlaxcala                   13
#  Veracruz                   18
#  Yucatán                   100
#  Zacatecas                  18
#
#  [32 rows x 1 columns],                      Huaraches
#  geoName
#  Aguascalientes              30
#  Baja California             34
#  Baja California Sur         50
#  Campeche                    49
#  Chiapas                     49
#  ...                        ...
#  Tamaulipas                  23
#  Tlaxcala                    25
#  Veracruz                    29
#  Yucatán                     39
#  Zacatecas                   42
#
#  [32 rows x 1 columns],                      Rosticería
#  geoName
#  Aguascalientes                0
#  Baja California               0
#  Baja California Sur           0
#  Campeche                      0
#  Chiapas                       0
#  ...                         ...
#  Tamaulipas                    0
#  Tlaxcala                      0
#  Veracruz                      0
#  Yucatán                       0
#  Zacatecas                     0
#
#  [32 rows x 1 columns],                      China
#  geoName
#  Aguascalientes          27
#  Baja California        100
#  Baja California Sur     64
#  Campeche                43
#  Chiapas                 45
#  ...                    ...
#  Tamaulipas              30
#  Tlaxcala                23
#  Veracruz                31
#  Yucatán                 55
#  Zacatecas               34
#
#  [32 rows x 1 columns],                      Yucateca
#  geoName
#  Aguascalientes              6
#  Baja California             2
#  Baja California Sur         0
#  Campeche                   22
#  Chiapas                     3
#  ...                       ...
#  Tamaulipas                  2
#  Tlaxcala                    3
#  Veracruz                    5
#  Yucatán                   100
#  Zacatecas                   3
#
#  [32 rows x 1 columns],                      Tabasqueña
#  geoName
#  Aguascalientes                0
#  Baja California               0
#  Baja California Sur           0
#  Campeche                     58
#  Chiapas                       4
#  ...                         ...
#  Tamaulipas                    0
#  Tlaxcala                      0
#  Veracruz                      3
#  Yucatán                      12
#  Zacatecas                     0
#
#  [32 rows x 1 columns],                      Arrachera
#  geoName
#  Aguascalientes              25
#  Baja California             16
#  Baja California Sur         38
#  Campeche                    35
#  Chiapas                     14
#  ...                        ...
#  Tamaulipas                  32
#  Tlaxcala                    21
#  Veracruz                    21
#  Yucatán                     40
#  Zacatecas                   23
#
#  [32 rows x 1 columns],                      Pastor
#  geoName
#  Aguascalientes           49
#  Baja California          32
#  Baja California Sur      55
#  Campeche                100
#  Chiapas                  48
#  ...                     ...
#  Tamaulipas               45
#  Tlaxcala                 59
#  Veracruz                 79
#  Yucatán                  92
#  Zacatecas                46
#
#  [32 rows x 1 columns],                      Birria
#  geoName
#  Aguascalientes           63
#  Baja California          82
#  Baja California Sur      65
#  Campeche                 13
#  Chiapas                  14
#  ...                     ...
#  Tamaulipas               12
#  Tlaxcala                 16
#  Veracruz                 20
#  Yucatán                  16
#  Zacatecas                80
#
#  [32 rows x 1 columns],                      Barbacoa
#  geoName
#  Aguascalientes             31
#  Baja California            38
#  Baja California Sur        34
#  Campeche                   51
#  Chiapas                    61
#  ...                       ...
#  Tamaulipas                 35
#  Tlaxcala                   34
#  Veracruz                   60
#  Yucatán                    31
#  Zacatecas                  28
#
#  [32 rows x 1 columns],                      Carnero
#  geoName
#  Aguascalientes            33
#  Baja California            8
#  Baja California Sur        0
#  Campeche                  21
#  Chiapas                   20
#  ...                      ...
#  Tamaulipas                17
#  Tlaxcala                  33
#  Veracruz                  18
#  Yucatán                  100
#  Zacatecas                  0
#
#  [32 rows x 1 columns],                      Pozole
#  geoName
#  Aguascalientes           28
#  Baja California          24
#  Baja California Sur      23
#  Campeche                 26
#  Chiapas                  18
#  ...                     ...
#  Tamaulipas               23
#  Tlaxcala                 23
#  Veracruz                 24
#  Yucatán                  25
#  Zacatecas                27
#
#  [32 rows x 1 columns],                      Enchiladas
#  geoName
#  Aguascalientes               80
#  Baja California              49
#  Baja California Sur          66
#  Campeche                     40
#  Chiapas                      35
#  ...                         ...
#  Tamaulipas                   59
#  Tlaxcala                     36
#  Veracruz                     53
#  Yucatán                      42
#  Zacatecas                   100
#
#  [32 rows x 1 columns],                      Chilaquiles
#  geoName
#  Aguascalientes                39
#  Baja California               70
#  Baja California Sur           88
#  Campeche                      66
#  Chiapas                       53
#  ...                          ...
#  Tamaulipas                    37
#  Tlaxcala                      36
#  Veracruz                      40
#  Yucatán                       77
#  Zacatecas                     41
#
#  [32 rows x 1 columns]]

# %% [markdown]
# ### Como los resultados nos los da por estados, filtramos y nos quedamos con las búsquedas en Yucatán.

# %%
busquedas = resultados[0].join(resultados[1:]).T
busquedas
# Out:
# geoName           Aguascalientes  Baja California  Baja California Sur  \
# Cocina Económica               0                0                    0
# Antojitos                     12               20                   19
# Pizza                         71               83                   74
# Hamburguesas                  71               76                   43
# Hot Dogs                      35               90                   73
# ...                          ...              ...                  ...
# Barbacoa                      31               38                   34
# Carnero                       33                8                    0
# Pozole                        28               24                   23
# Enchiladas                    80               49                   66
# Chilaquiles                   39               70                   88
#
# geoName           Campeche  Chiapas  Chihuahua  Ciudad de México  \
# Cocina Económica         0        0          0                21
# Antojitos              100       30         28                18
# Pizza                   77       79         64                84
# Hamburguesas            54       44         82                75
# Hot Dogs                 0       20         44                43
# ...                    ...      ...        ...               ...
# Barbacoa                51       61         58                39
# Carnero                 21       20         11                60
# Pozole                  26       18         18                25
# Enchiladas              40       35         61                54
# Chilaquiles             66       53         33                62
#
# geoName           Coahuila de Zaragoza  Colima  Durango  ...  Quintana Roo  \
# Cocina Económica                     0       0        0  ...             0
# Antojitos                           11      36       30  ...            47
# Pizza                               70      80       64  ...            99
# Hamburguesas                        77     100       58  ...            50
# Hot Dogs                            39      59       37  ...            42
# ...                                ...     ...      ...  ...           ...
# Barbacoa                            37     100       39  ...            45
# Carnero                             17       0       21  ...            33
# Pozole                              20     100       19  ...            26
# Enchiladas                          72      89       85  ...            58
# Chilaquiles                         65      62       65  ...            99
#
# geoName           San Luis Potosí  Sinaloa  Sonora  Tabasco  Tamaulipas  \
# Cocina Económica                0        0       0        0           0
# Antojitos                      39       22      19       40          25
# Pizza                          82       73      74       76          62
# Hamburguesas                   60       89      83       53          62
# Hot Dogs                       25      100      99       31          43
# ...                           ...      ...     ...      ...         ...
# Barbacoa                       43       51      59       94          35
# Carnero                        20        9      12        5          17
# Pozole                         42       20      21       25          23
# Enchiladas                     94       77      51       60          59
# Chilaquiles                    42       59      50       73          37
#
# geoName           Tlaxcala  Veracruz  Yucatán  Zacatecas
# Cocina Económica         0         0      100          0
# Antojitos               18        58       33         30
# Pizza                   39        64      100         45
# Hamburguesas            39        60       53         76
# Hot Dogs                 0        33       28          0
# ...                    ...       ...      ...        ...
# Barbacoa                34        60       31         28
# Carnero                 33        18      100          0
# Pozole                  23        24       25         27
# Enchiladas              36        53       42        100
# Chilaquiles             36        40       77         41
#
# [41 rows x 32 columns]

# %%
trends = busquedas['Yucatán'].sort_values(ascending=False)
trends
# Out:
# Cocina Económica    100
# Parrilla            100
# Pizza               100
# Carnero             100
# Panuchos            100
#                    ...
# Gorditas             18
# Birria               16
# Menudo               13
# Tabasqueña           12
# Rosticería            0
# Name: Yucatán, Length: 41, dtype: int64

# %%
df['GoogleTrend'] = trends
df
# Out:
#                   InegiCount  GoogleTrend
# Index
# Cocina Económica        1409          100
# Antojitos               1030           33
# Pizza                    309          100
# Hamburguesas             149           53
# Hot Dogs                  36           28
# ...                      ...          ...
# Barbacoa                  15           31
# Carnero                    1          100
# Pozole                    12           25
# Enchiladas                 1           42
# Chilaquiles                0           77
#
# [41 rows x 2 columns]

# %% [markdown]
# ## Interest over time

# %%
iot = {}
for comida in inegi_results:
    print(comida)
    pytrends.build_payload([comida], cat=71, geo='MX', gprop='')
    iot[comida] = pytrends.interest_over_time()
    
iot
# Out:
# Cocina Económica
# Antojitos
# Pizza
# Hamburguesas
# Hot Dogs
# Sushi
# Tamales
# Mariscos
# Pescado
# Tacos
# Carne
# Asada
# Panuchos
# Cochinita
# Pollo
# Desayunos
# Tortas
# Mondongo
# Menudo
# Memelas
# Empanadas
# Chicharrón
# Gorditas
# Costillas
# Carnitas
# Doraditas
# Baguettes
# Parrilla
# Huaraches
# Rosticería
# China
# Yucateca
# Tabasqueña
# Arrachera
# Pastor
# Birria
# Barbacoa
# Carnero
# Pozole
# Enchiladas
# Chilaquiles
# {'Cocina Económica':             Cocina Económica isPartial
#  date
#  2015-03-08                 0     False
#  2015-03-15                 0     False
#  2015-03-22                42     False
#  2015-03-29                46     False
#  2015-04-05                 0     False
#  ...                      ...       ...
#  2020-02-02                28     False
#  2020-02-09                54     False
#  2020-02-16                26     False
#  2020-02-23                26     False
#  2020-03-01                 0      True
#
#  [261 rows x 2 columns], 'Antojitos':             Antojitos isPartial
#  date
#  2015-03-08         24     False
#  2015-03-15         20     False
#  2015-03-22         22     False
#  2015-03-29         13     False
#  2015-04-05         22     False
#  ...               ...       ...
#  2020-02-02         43     False
#  2020-02-09         34     False
#  2020-02-16         34     False
#  2020-02-23         36     False
#  2020-03-01         61      True
#
#  [261 rows x 2 columns], 'Pizza':             Pizza isPartial
#  date
#  2015-03-08     33     False
#  2015-03-15     37     False
#  2015-03-22     34     False
#  2015-03-29     46     False
#  2015-04-05     32     False
#  ...           ...       ...
#  2020-02-02     57     False
#  2020-02-09     57     False
#  2020-02-16     47     False
#  2020-02-23     46     False
#  2020-03-01    100      True
#
#  [261 rows x 2 columns], 'Hamburguesas':             Hamburguesas isPartial
#  date
#  2015-03-08            12     False
#  2015-03-15            11     False
#  2015-03-22            13     False
#  2015-03-29            14     False
#  2015-04-05            15     False
#  ...                  ...       ...
#  2020-02-02            22     False
#  2020-02-09            20     False
#  2020-02-16            19     False
#  2020-02-23            19     False
#  2020-03-01            32      True
#
#  [261 rows x 2 columns], 'Hot Dogs':             Hot Dogs isPartial
#  date
#  2015-03-08        36     False
#  2015-03-15        55     False
#  2015-03-22        42     False
#  2015-03-29        38     False
#  2015-04-05        63     False
#  ...              ...       ...
#  2020-02-02        67     False
#  2020-02-09        61     False
#  2020-02-16        55     False
#  2020-02-23        53     False
#  2020-03-01        76      True
#
#  [261 rows x 2 columns], 'Sushi':             Sushi isPartial
#  date
#  2015-03-08     40     False
#  2015-03-15     42     False
#  2015-03-22     39     False
#  2015-03-29     53     False
#  2015-04-05     42     False
#  ...           ...       ...
#  2020-02-02     74     False
#  2020-02-09     85     False
#  2020-02-16     69     False
#  2020-02-23     72     False
#  2020-03-01     91      True
#
#  [261 rows x 2 columns], 'Tamales':             Tamales isPartial
#  date
#  2015-03-08       10     False
#  2015-03-15       10     False
#  2015-03-22        9     False
#  2015-03-29        9     False
#  2015-04-05        9     False
#  ...             ...       ...
#  2020-02-02       54     False
#  2020-02-09       16     False
#  2020-02-16       12     False
#  2020-02-23       12     False
#  2020-03-01       12      True
#
#  [261 rows x 2 columns], 'Mariscos':             Mariscos isPartial
#  date
#  2015-03-08        28     False
#  2015-03-15        25     False
#  2015-03-22        27     False
#  2015-03-29        52     False
#  2015-04-05        21     False
#  ...              ...       ...
#  2020-02-02        48     False
#  2020-02-09        50     False
#  2020-02-16        51     False
#  2020-02-23        57     False
#  2020-03-01        76      True
#
#  [261 rows x 2 columns], 'Pescado':             Pescado isPartial
#  date
#  2015-03-08       38     False
#  2015-03-15       38     False
#  2015-03-22       37     False
#  2015-03-29       77     False
#  2015-04-05       32     False
#  ...             ...       ...
#  2020-02-02       34     False
#  2020-02-09       34     False
#  2020-02-16       36     False
#  2020-02-23       51     False
#  2020-03-01       46      True
#
#  [261 rows x 2 columns], 'Tacos':             Tacos isPartial
#  date
#  2015-03-08     38     False
#  2015-03-15     41     False
#  2015-03-22     37     False
#  2015-03-29     45     False
#  2015-04-05     39     False
#  ...           ...       ...
#  2020-02-02     80     False
#  2020-02-09     76     False
#  2020-02-16     74     False
#  2020-02-23     74     False
#  2020-03-01    100      True
#
#  [261 rows x 2 columns], 'Carne':             Carne isPartial
#  date
#  2015-03-08     38     False
#  2015-03-15     40     False
#  2015-03-22     36     False
#  2015-03-29     38     False
#  2015-04-05     50     False
#  ...           ...       ...
#  2020-02-02     66     False
#  2020-02-09     64     False
#  2020-02-16     64     False
#  2020-02-23     62     False
#  2020-03-01     64      True
#
#  [261 rows x 2 columns], 'Asada':             Asada isPartial
#  date
#  2015-03-08     11     False
#  2015-03-15     10     False
#  2015-03-22     10     False
#  2015-03-29     10     False
#  2015-04-05     10     False
#  ...           ...       ...
#  2020-02-02     22     False
#  2020-02-09     20     False
#  2020-02-16     21     False
#  2020-02-23     20     False
#  2020-03-01     30      True
#
#  [261 rows x 2 columns], 'Panuchos':             Panuchos isPartial
#  date
#  2015-03-08        50     False
#  2015-03-15        33     False
#  2015-03-22        41     False
#  2015-03-29        20     False
#  2015-04-05        37     False
#  ...              ...       ...
#  2020-02-02       100     False
#  2020-02-09        48     False
#  2020-02-16        61     False
#  2020-02-23        67     False
#  2020-03-01        94      True
#
#  [261 rows x 2 columns], 'Cochinita':             Cochinita isPartial
#  date
#  2015-03-08         39     False
#  2015-03-15         39     False
#  2015-03-22         40     False
#  2015-03-29         34     False
#  2015-04-05         43     False
#  ...               ...       ...
#  2020-02-02         49     False
#  2020-02-09         44     False
#  2020-02-16         52     False
#  2020-02-23         47     False
#  2020-03-01         68      True
#
#  [261 rows x 2 columns], 'Pollo':             Pollo isPartial
#  date
#  2015-03-08     53     False
#  2015-03-15     53     False
#  2015-03-22     50     False
#  2015-03-29     54     False
#  2015-04-05     51     False
#  ...           ...       ...
#  2020-02-02     81     False
#  2020-02-09     77     False
#  2020-02-16     74     False
#  2020-02-23     77     False
#  2020-03-01     81      True
#
#  [261 rows x 2 columns], 'Desayunos':             Desayunos isPartial
#  date
#  2015-03-08         55     False
#  2015-03-15         62     False
#  2015-03-22         46     False
#  2015-03-29         66     False
#  2015-04-05         56     False
#  ...               ...       ...
#  2020-02-02         83     False
#  2020-02-09         77     False
#  2020-02-16         80     False
#  2020-02-23         79     False
#  2020-03-01        100      True
#
#  [261 rows x 2 columns], 'Tortas':             Tortas isPartial
#  date
#  2015-03-08      46     False
#  2015-03-15      50     False
#  2015-03-22      50     False
#  2015-03-29      66     False
#  2015-04-05      44     False
#  ...            ...       ...
#  2020-02-02      64     False
#  2020-02-09      63     False
#  2020-02-16      58     False
#  2020-02-23      68     False
#  2020-03-01     100      True
#
#  [261 rows x 2 columns], 'Mondongo':             Mondongo isPartial
#  date
#  2015-03-08         9     False
#  2015-03-15         5     False
#  2015-03-22        18     False
#  2015-03-29        20     False
#  2015-04-05        14     False
#  ...              ...       ...
#  2020-02-02        42     False
#  2020-02-09        35     False
#  2020-02-16        26     False
#  2020-02-23        27     False
#  2020-03-01        56      True
#
#  [261 rows x 2 columns], 'Menudo':             Menudo isPartial
#  date
#  2015-03-08      15     False
#  2015-03-15      17     False
#  2015-03-22      11     False
#  2015-03-29      15     False
#  2015-04-05       8     False
#  ...            ...       ...
#  2020-02-02      27     False
#  2020-02-09      26     False
#  2020-02-16      21     False
#  2020-02-23      26     False
#  2020-03-01      42      True
#
#  [261 rows x 2 columns], 'Memelas':             Memelas isPartial
#  date
#  2015-03-08       20     False
#  2015-03-15       24     False
#  2015-03-22       28     False
#  2015-03-29       46     False
#  2015-04-05       22     False
#  ...             ...       ...
#  2020-02-02       48     False
#  2020-02-09       56     False
#  2020-02-16       36     False
#  2020-02-23       54     False
#  2020-03-01       60      True
#
#  [261 rows x 2 columns], 'Empanadas':             Empanadas isPartial
#  date
#  2015-03-08         19     False
#  2015-03-15         20     False
#  2015-03-22         18     False
#  2015-03-29         28     False
#  2015-04-05         20     False
#  ...               ...       ...
#  2020-02-02         21     False
#  2020-02-09         20     False
#  2020-02-16         19     False
#  2020-02-23         21     False
#  2020-03-01         23      True
#
#  [261 rows x 2 columns], 'Chicharrón':             Chicharrón isPartial
#  date
#  2015-03-08          12     False
#  2015-03-15          10     False
#  2015-03-22          22     False
#  2015-03-29          17     False
#  2015-04-05          25     False
#  ...                ...       ...
#  2020-02-02          89     False
#  2020-02-09          77     False
#  2020-02-16          83     False
#  2020-02-23          78     False
#  2020-03-01          34      True
#
#  [261 rows x 2 columns], 'Gorditas':             Gorditas isPartial
#  date
#  2015-03-08        61     False
#  2015-03-15        50     False
#  2015-03-22        43     False
#  2015-03-29        42     False
#  2015-04-05        46     False
#  ...              ...       ...
#  2020-02-02        77     False
#  2020-02-09        69     False
#  2020-02-16        73     False
#  2020-02-23        70     False
#  2020-03-01        64      True
#
#  [261 rows x 2 columns], 'Costillas':             Costillas isPartial
#  date
#  2015-03-08         14     False
#  2015-03-15         14     False
#  2015-03-22         12     False
#  2015-03-29         13     False
#  2015-04-05         15     False
#  ...               ...       ...
#  2020-02-02         19     False
#  2020-02-09         16     False
#  2020-02-16         15     False
#  2020-02-23         16     False
#  2020-03-01         17      True
#
#  [261 rows x 2 columns], 'Carnitas':             Carnitas isPartial
#  date
#  2015-03-08        35     False
#  2015-03-15        32     False
#  2015-03-22        29     False
#  2015-03-29        30     False
#  2015-04-05        29     False
#  ...              ...       ...
#  2020-02-02        67     False
#  2020-02-09        65     False
#  2020-02-16        60     False
#  2020-02-23        68     False
#  2020-03-01        84      True
#
#  [261 rows x 2 columns], 'Doraditas':             Doraditas isPartial
#  date
#  2015-03-08         16     False
#  2015-03-15         17     False
#  2015-03-22         42     False
#  2015-03-29         40     False
#  2015-04-05         35     False
#  ...               ...       ...
#  2020-02-02         36     False
#  2020-02-09         50     False
#  2020-02-16         23     False
#  2020-02-23         34     False
#  2020-03-01         94      True
#
#  [261 rows x 2 columns], 'Baguettes':             Baguettes isPartial
#  date
#  2015-03-08         43     False
#  2015-03-15         49     False
#  2015-03-22         36     False
#  2015-03-29         40     False
#  2015-04-05         35     False
#  ...               ...       ...
#  2020-02-02         24     False
#  2020-02-09         46     False
#  2020-02-16         46     False
#  2020-02-23         34     False
#  2020-03-01          0      True
#
#  [261 rows x 2 columns], 'Parrilla':             Parrilla isPartial
#  date
#  2015-03-08        33     False
#  2015-03-15        33     False
#  2015-03-22        39     False
#  2015-03-29        42     False
#  2015-04-05        32     False
#  ...              ...       ...
#  2020-02-02        59     False
#  2020-02-09        67     False
#  2020-02-16        66     False
#  2020-02-23        60     False
#  2020-03-01       100      True
#
#  [261 rows x 2 columns], 'Huaraches':             Huaraches isPartial
#  date
#  2015-03-08         44     False
#  2015-03-15         36     False
#  2015-03-22         35     False
#  2015-03-29         47     False
#  2015-04-05         31     False
#  ...               ...       ...
#  2020-02-02         52     False
#  2020-02-09         73     False
#  2020-02-16         64     False
#  2020-02-23         76     False
#  2020-03-01         84      True
#
#  [261 rows x 2 columns], 'Rosticería':             Rosticería isPartial
#  date
#  2015-03-08           0     False
#  2015-03-15           0     False
#  2015-03-22           0     False
#  2015-03-29         100     False
#  2015-04-05           0     False
#  ...                ...       ...
#  2020-02-02           0     False
#  2020-02-09           0     False
#  2020-02-16          58     False
#  2020-02-23          57     False
#  2020-03-01           0      True
#
#  [261 rows x 2 columns], 'China':             China isPartial
#  date
#  2015-03-08     22     False
#  2015-03-15     27     False
#  2015-03-22     27     False
#  2015-03-29     24     False
#  2015-04-05    100     False
#  ...           ...       ...
#  2020-02-02     39     False
#  2020-02-09     37     False
#  2020-02-16     35     False
#  2020-02-23     34     False
#  2020-03-01     40      True
#
#  [261 rows x 2 columns], 'Yucateca':             Yucateca isPartial
#  date
#  2015-03-08        47     False
#  2015-03-15        56     False
#  2015-03-22        46     False
#  2015-03-29        31     False
#  2015-04-05        40     False
#  ...              ...       ...
#  2020-02-02        59     False
#  2020-02-09        75     False
#  2020-02-16        55     False
#  2020-02-23        67     False
#  2020-03-01        39      True
#
#  [261 rows x 2 columns], 'Tabasqueña':             Tabasqueña isPartial
#  date
#  2015-03-08          25     False
#  2015-03-15          26     False
#  2015-03-22          19     False
#  2015-03-29           0     False
#  2015-04-05          18     False
#  ...                ...       ...
#  2020-02-02          43     False
#  2020-02-09          29     False
#  2020-02-16          12     False
#  2020-02-23          12     False
#  2020-03-01         100      True
#
#  [261 rows x 2 columns], 'Arrachera':             Arrachera isPartial
#  date
#  2015-03-08         28     False
#  2015-03-15         41     False
#  2015-03-22         29     False
#  2015-03-29         29     False
#  2015-04-05         31     False
#  ...               ...       ...
#  2020-02-02         57     False
#  2020-02-09         59     False
#  2020-02-16         57     False
#  2020-02-23         59     False
#  2020-03-01         71      True
#
#  [261 rows x 2 columns], 'Pastor':             Pastor isPartial
#  date
#  2015-03-08      37     False
#  2015-03-15      35     False
#  2015-03-22      43     False
#  2015-03-29      40     False
#  2015-04-05      38     False
#  ...            ...       ...
#  2020-02-02      59     False
#  2020-02-09      58     False
#  2020-02-16      62     False
#  2020-02-23      61     False
#  2020-03-01      98      True
#
#  [261 rows x 2 columns], 'Birria':             Birria isPartial
#  date
#  2015-03-08      21     False
#  2015-03-15      32     False
#  2015-03-22      18     False
#  2015-03-29      19     False
#  2015-04-05      19     False
#  ...            ...       ...
#  2020-02-02      58     False
#  2020-02-09      45     False
#  2020-02-16      49     False
#  2020-02-23      40     False
#  2020-03-01      69      True
#
#  [261 rows x 2 columns], 'Barbacoa':             Barbacoa isPartial
#  date
#  2015-03-08        22     False
#  2015-03-15        27     False
#  2015-03-22        22     False
#  2015-03-29        24     False
#  2015-04-05        27     False
#  ...              ...       ...
#  2020-02-02        51     False
#  2020-02-09        43     False
#  2020-02-16        51     False
#  2020-02-23        43     False
#  2020-03-01        62      True
#
#  [261 rows x 2 columns], 'Carnero':             Carnero isPartial
#  date
#  2015-03-08       37     False
#  2015-03-15       52     False
#  2015-03-22       36     False
#  2015-03-29       27     False
#  2015-04-05       31     False
#  ...             ...       ...
#  2020-02-02       14     False
#  2020-02-09       34     False
#  2020-02-16       26     False
#  2020-02-23       38     False
#  2020-03-01       96      True
#
#  [261 rows x 2 columns], 'Pozole':             Pozole isPartial
#  date
#  2015-03-08      11     False
#  2015-03-15      12     False
#  2015-03-22      11     False
#  2015-03-29       8     False
#  2015-04-05       9     False
#  ...            ...       ...
#  2020-02-02      21     False
#  2020-02-09      18     False
#  2020-02-16      18     False
#  2020-02-23      16     False
#  2020-03-01      24      True
#
#  [261 rows x 2 columns], 'Enchiladas':             Enchiladas isPartial
#  date
#  2015-03-08          60     False
#  2015-03-15          60     False
#  2015-03-22          54     False
#  2015-03-29          55     False
#  2015-04-05          65     False
#  ...                ...       ...
#  2020-02-02          81     False
#  2020-02-09          85     False
#  2020-02-16          88     False
#  2020-02-23          85     False
#  2020-03-01          83      True
#
#  [261 rows x 2 columns], 'Chilaquiles':             Chilaquiles isPartial
#  date
#  2015-03-08           39     False
#  2015-03-15           50     False
#  2015-03-22           35     False
#  2015-03-29           46     False
#  2015-04-05           41     False
#  ...                 ...       ...
#  2020-02-02           76     False
#  2020-02-09           76     False
#  2020-02-16           78     False
#  2020-02-23           71     False
#  2020-03-01           90      True
#
#  [261 rows x 2 columns]}

# %%
import matplotlib.pyplot as plt

x = [i+1 for i in range(len(iot['Desayunos']['Desayunos']))]

#for food in foods:
plt.plot(x, iot['Desayunos']['Desayunos'].values);

# %%
iot['Gorditas']
# Out:
#             Gorditas isPartial
# date
# 2015-03-08        61     False
# 2015-03-15        50     False
# 2015-03-22        43     False
# 2015-03-29        42     False
# 2015-04-05        46     False
# ...              ...       ...
# 2020-02-02        77     False
# 2020-02-09        69     False
# 2020-02-16        73     False
# 2020-02-23        70     False
# 2020-03-01        64      True
#
# [261 rows x 2 columns]

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()

slope = {}
for food in foods:
    linreg.fit(np.array(x).reshape(-1,1), iot[food][food].values)
    slope[food] = linreg.intercept_

slope
# Out:
# {'Cocina Económica': 5.914382552313588,
#  'Antojitos': 20.597907456528144,
#  'Pizza': 37.696463306808134,
#  'Hamburguesas': 10.257058650162097,
#  'Hot Dogs': 43.80462717359269,
#  'Sushi': 44.261626878868256,
#  'Tamales': 13.530150309460652,
#  'Mariscos': 21.444827586206898,
#  'Pescado': 29.52402004126142,
#  'Tacos': 38.14291187739464,
#  'Carne': 40.734217506631296,
#  'Asada': 11.27444739168877,
#  'Panuchos': 31.06044798113763,
#  'Cochinita': 44.97147067491895,
#  'Pollo': 56.13009136457413,
#  'Desayunos': 58.58352490421455,
#  'Tortas': 50.62861774241084,
#  'Mondongo': 13.745564397288536,
#  'Menudo': 15.036693191865606,
#  'Memelas': 22.83575007368111,
#  'Empanadas': 19.913351016799293,
#  'Chicharrón': 4.320778072502211,
#  'Gorditas': 49.99183613321544,
#  'Costillas': 15.812054229295608,
#  'Carnitas': 31.09053934571177,
#  'Doraditas': 27.270999115826704,
#  'Baguettes': 46.14945475979958,
#  'Parrilla': 31.185470085470087,
#  'Huaraches': 36.84134983790156,
#  'Rosticería': 6.518302387267905,
#  'China': 21.894252873563218,
#  'Yucateca': 46.25820807544945,
#  'Tabasqueña': 28.60200412614206,
#  'Arrachera': 29.29442970822281,
#  'Pastor': 44.895254936634245,
#  'Birria': 22.34344238137341,
#  'Barbacoa': 24.722634836427943,
#  'Carnero': 28.981756557618628,
#  'Pozole': 13.468936044798113,
#  'Enchiladas': 59.52740937223696,
#  'Chilaquiles': 38.67765988800471}

# %%
df['slope'] = ''
for key in slope:
    df['slope'].loc[key] = slope[key]
df.slope = df.slope.astype('float64')
df.dtypes
# Out:
# InegiCount       int64
# GoogleTrend      int64
# slope          float64
# dtype: object

# %% [markdown]
# ### Con esto, tenemos parametrizado el interés en el estado por cada uno de los giros de comida.
# ### Ahora, necesitamos revisar el grado de satisfacción de los usuarios por la oferta existente.

# %% [markdown]
# # Yelp

# %% [markdown]
# ### Utilizando la API de Yelp, hacemos búsquedas nuevamente sobre los diferentes giros de comida para encontrar negocios y sus calificaciónes en la plataforma.

# %%
import requests
from bs4 import BeautifulSoup as bs
import json

# %%
client_id = 'JPrLnyol5AaT0XLf7CYbWg'
api_key = '5F0kTJmEIUsrAXKEcpqHA_HvL2uKWA3HZC_iQ73dGgIXgke7fCh84CBP5KpwVMXumfm4BahGo3iaBiNtBi9Q9vexfphH6urta05XSFaaQCs6aphzSQfWwhWSo_6nXHYx'
app_name = 'ravenous'

endpoint = 'https://api.yelp.com/v3/businesses/search?'
req_parameters_1 = ['location']
req_parameters_2 = ['latitud', 'longitude']
optional_parameters = ['term', 'radius', 'categories', 'locale', 'limit', 'sort_by', 'price']

# %%
yelp_search = []
for comida in foods:
    term = 'term={}&'.format(comida)
    print(term)
    location = 'latitude=21.007038700000003&longitude=-89.71818643311036&'
    locale = 'locale=es_MX&'
    radius = 'radius=3000&'
    limit = 'limit=50' 
    res = requests.get(endpoint+term+location+locale+radius+limit, headers={'Authorization':'Bearer '+api_key})
    soup = bs(res.content)
    yelp_json = json.loads(soup.findAll('p')[0].text)
    ydf = pd.DataFrame(yelp_json['businesses'])
    ydf['tipo'] = comida
    yelp_search.append(ydf)
    
yelp_search
# Out:
# term=Cocina Económica&
# term=Antojitos&
# term=Pizza&
# term=Hamburguesas&
# term=Hot Dogs&
# term=Sushi&
# term=Tamales&
# term=Mariscos&
# term=Pescado&
# term=Tacos&
# term=Carne&
# term=Asada&
# term=Panuchos&
# term=Cochinita&
# term=Pollo&
# term=Desayunos&
# term=Tortas&
# term=Mondongo&
# term=Menudo&
# term=Memelas&
# term=Empanadas&
# term=Chicharrón&
# term=Gorditas&
# term=Costillas&
# term=Carnitas&
# term=Doraditas&
# term=Baguettes&
# term=Parrilla&
# term=Huaraches&
# term=Rosticería&
# term=China&
# term=Yucateca&
# term=Tabasqueña&
# term=Arrachera&
# term=Pastor&
# term=Birria&
# term=Barbacoa&
# term=Carnero&
# term=Pozole&
# term=Enchiladas&
# term=Chilaquiles&
# [Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [],                        id                             alias  \
#  0  KeRV9bkIUlV_2ROX3XbAeg                    baleros-mérida
#  1  -Nvh7oy7_U9C-JGW8EiF0A                   papitzza-mérida
#  2  bO9dWhFxdQ-zs0mfib7vrw          pizzeria-bernardi-mérida
#  3  svFqSohn16FFhfIfzlKGFw          l-ora-della-pizza-mérida
#  4  XSemDWcz5HISvGnNB80FLQ    messina-s-caucel-ciudad-caucel
#  5  HIeFOPyTI-45__9uuBGDQg                 tunkuruchu-mérida
#  6  rnx5P5-kq1fOZZWT6pp1xw  luigis-pizza-y-suchito-go-mérida
#
#                          name  \
#  0                   Balero's
#  1                   Papitzza
#  2          Pizzeria Bernardi
#  3          L'ora della Pizza
#  4           Messina´s Caucel
#  5                 Tunkuruchu
#  6  Luigis Pizza & Suchito-Go
#
#                                             image_url  is_closed  \
#  0  https://s3-media3.fl.yelpcdn.com/bphoto/w3Ic5J...      False
#  1  https://s3-media1.fl.yelpcdn.com/bphoto/cBOU2Y...      False
#  2  https://s3-media4.fl.yelpcdn.com/bphoto/n5zzjS...      False
#  3  https://s3-media3.fl.yelpcdn.com/bphoto/NlVuwP...      False
#  4                                                         False
#  5  https://s3-media2.fl.yelpcdn.com/bphoto/Uo7y6e...      False
#  6  https://s3-media2.fl.yelpcdn.com/bphoto/XNj041...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/baleros-m%C3%A9rid...            10
#  1  https://www.yelp.com.mx/biz/papitzza-m%C3%A9ri...             1
#  2  https://www.yelp.com.mx/biz/pizzeria-bernardi-...             2
#  3  https://www.yelp.com.mx/biz/l-ora-della-pizza-...             5
#  4  https://www.yelp.com.mx/biz/messina-s-caucel-c...             1
#  5  https://www.yelp.com.mx/biz/tunkuruchu-m%C3%A9...             5
#  6  https://www.yelp.com.mx/biz/luigis-pizza-y-suc...             2
#
#                                            categories  rating  \
#  0          [{'alias': 'pizza', 'title': 'Pizzería'}]     3.5
#  1          [{'alias': 'pizza', 'title': 'Pizzería'}]     3.0
#  2          [{'alias': 'pizza', 'title': 'Pizzería'}]     4.5
#  3  [{'alias': 'pizza', 'title': 'Pizzería'}, {'al...     4.0
#  4          [{'alias': 'pizza', 'title': 'Pizzería'}]     4.0
#  5  [{'alias': 'pizza', 'title': 'Pizzería'}, {'al...     3.5
#  6                                                 []     3.5
#
#                                           coordinates transactions price  \
#  0  {'latitude': 21.0017109105729, 'longitude': -8...           []     $
#  1  {'latitude': 20.9965518874432, 'longitude': -8...           []   NaN
#  2  {'latitude': 21.0002995, 'longitude': -89.5464...           []   NaN
#  3  {'latitude': 20.9934759206305, 'longitude': -8...           []    $$
#  4  {'latitude': 20.9866104, 'longitude': -89.7020...           []   NaN
#  5  {'latitude': 20.9960310304735, 'longitude': -8...           []   NaN
#  6  {'latitude': 20.9974865338512, 'longitude': -8...           []   NaN
#
#                                              location          phone  \
#  0  {'address1': 'Av 88 695 Sol Caucel', 'address2...  +529999409595
#  1  {'address1': 'Av. 59 Los Almendros, Cd. Caucel...  +529993127295
#  2  {'address1': 'Calle 35', 'address2': 'por 48 A...  +529999889059
#  3  {'address1': 'Av. 88 Los Almendros, Cd. Caucel...  +529992678237
#  4  {'address1': 'Calle 70 no. 635', 'address2': '...
#  5  {'address1': 'Av. 59', 'address2': 'Ciudad Cau...  +529993308583
#  6  {'address1': 'Av. 88 Los Almendros, Cd. Caucel...  +529997394788
#
#       display_phone     distance   tipo
#  0  01 999 940 9595  1695.884969  Pizza
#  1  01 999 312 7295  1929.592345  Pizza
#  2  01 999 988 9059   333.746571  Pizza
#  3  01 999 267 8237  2054.603163  Pizza
#  4                   2569.961573  Pizza
#  5  01 999 330 8583  2221.344951  Pizza
#  6  01 999 739 4788  1812.208710  Pizza  ,                        id                  alias            name  \
#  0  9PV0MFXwWv_2oM9AoOByHQ  vocho-s-burger-mérida  Vocho´s Burger
#  1  oAHh2RzomP5aS7CmvtFvQw      la-perrera-mérida      La Perrera
#  2  X21vjs_9xMmQTH77oWmG7Q     happy-doggy-mérida     Happy Doggy
#  3  ayHe75eNnHSFA-YbeR02SQ    tierra-nueva-mérida    Tierra Nueva
#
#                                             image_url  is_closed  \
#  0  https://s3-media3.fl.yelpcdn.com/bphoto/qzPMOj...      False
#  1  https://s3-media3.fl.yelpcdn.com/bphoto/1ruVd6...      False
#  2  https://s3-media3.fl.yelpcdn.com/bphoto/Tb8Kr0...      False
#  3  https://s3-media1.fl.yelpcdn.com/bphoto/s5SVpm...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/vocho-s-burger-m%C...             1
#  1  https://www.yelp.com.mx/biz/la-perrera-m%C3%A9...             1
#  2  https://www.yelp.com.mx/biz/happy-doggy-m%C3%A...             1
#  3  https://www.yelp.com.mx/biz/tierra-nueva-m%C3%...             1
#
#                                            categories  rating  \
#  0    [{'alias': 'burgers', 'title': 'Hamburguesas'}]     4.0
#  1  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...     5.0
#  2  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...     5.0
#  3  [{'alias': 'vegetarian', 'title': 'Cocina vege...     5.0
#
#                                           coordinates transactions  \
#  0  {'latitude': 20.9962113273225, 'longitude': -8...           []
#  1  {'latitude': 21.0052448527215, 'longitude': -8...           []
#  2  {'latitude': 20.9961503473224, 'longitude': -8...           []
#  3  {'latitude': 21.0146999, 'longitude': -89.7003...           []
#
#                                              location          phone  \
#  0  {'address1': 'Av. 59 660 Los almendros, Cd. Ca...  +529993071768
#  1  {'address1': 'Av. 106 S/N', 'address2': 'Col. ...  +529999687527
#  2  {'address1': 'Av. 59 Los Almendros, Cd. Caucel...
#  3  {'address1': 'calle 37d esquina con 12', 'addr...
#
#       display_phone     distance          tipo
#  0  01 999 307 1768  2212.228918  Hamburguesas
#  1  01 999 968 7527   285.954386  Hamburguesas
#  2                   2477.565743  Hamburguesas
#  3                    135.683932  Hamburguesas  ,                        id               alias         name  \
#  0  X21vjs_9xMmQTH77oWmG7Q  happy-doggy-mérida  Happy Doggy
#  1  oAHh2RzomP5aS7CmvtFvQw   la-perrera-mérida   La Perrera
#
#                                             image_url  is_closed  \
#  0  https://s3-media3.fl.yelpcdn.com/bphoto/Tb8Kr0...      False
#  1  https://s3-media3.fl.yelpcdn.com/bphoto/1ruVd6...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/happy-doggy-m%C3%A...             1
#  1  https://www.yelp.com.mx/biz/la-perrera-m%C3%A9...             1
#
#                                            categories  rating  \
#  0  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...     5.0
#  1  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...     5.0
#
#                                           coordinates transactions  \
#  0  {'latitude': 20.9961503473224, 'longitude': -8...           []
#  1  {'latitude': 21.0052448527215, 'longitude': -8...           []
#
#                                              location          phone  \
#  0  {'address1': 'Av. 59 Los Almendros, Cd. Caucel...
#  1  {'address1': 'Av. 106 S/N', 'address2': 'Col. ...  +529999687527
#
#       display_phone     distance      tipo
#  0                   2477.565743  Hot Dogs
#  1  01 999 968 7527   285.954386  Hot Dogs  ,                        id                alias          name  \
#  0  iA9SaUCkhQKDLjjL3Y7EYA  shogun-sushi-mérida  Shogun Sushi
#
#                                             image_url  is_closed  \
#  0  https://s3-media2.fl.yelpcdn.com/bphoto/hsBXIq...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/shogun-sushi-m%C3%...             3
#
#                                            categories  rating  \
#  0  [{'alias': 'sushi', 'title': 'Sushi'}, {'alias...     3.5
#
#                                           coordinates transactions  \
#  0  {'latitude': 21.0080503437205, 'longitude': -8...           []
#
#                                              location phone display_phone  \
#  0  {'address1': 'Av 32 Plaza Velaire, Ciudad Cauc...
#
#       distance   tipo
#  0  2537.70323  Sushi  , Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [],                        id                                    alias  \
#  0  v_rAzbKcGvSAwr2YaVuJjg  tortas-y-tacos-de-asado-de-la-59-mérida
#  1  arPWgmLlIEELblyQgFbSIA      tortas-de-cochinita-de-la-59-mérida
#  2  uIzLqC0QZaARgOehohKb8g                    tacos-coyoacán-mérida
#  3  FgDFR8tCiae2MfYxoBWoNg                      osama-ciudad-caucel
#  4  XDme8Qi0ifJdMBhdb9RzCw                  terraza-caucel-mérida-2
#  5  Bgqj8kkHuBgpVgihyFdfYA          tortas-la-familia-ciudad-caucel
#
#                                 name  \
#  0  Tortas y tacos de Asado de la 59
#  1      Tortas de cochinita de la 59
#  2                    Tacos Coyoacán
#  3                             Osama
#  4                    Terraza Caucel
#  5                 Tortas La Familia
#
#                                             image_url  is_closed  \
#  0  https://s3-media1.fl.yelpcdn.com/bphoto/69p5Lk...      False
#  1                                                         False
#  2                                                         False
#  3  https://s3-media2.fl.yelpcdn.com/bphoto/3bo6X7...      False
#  4  https://s3-media2.fl.yelpcdn.com/bphoto/WdfKUd...      False
#  5  https://s3-media3.fl.yelpcdn.com/bphoto/3UqfPd...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/tortas-y-tacos-de-...             2
#  1  https://www.yelp.com.mx/biz/tortas-de-cochinit...             1
#  2  https://www.yelp.com.mx/biz/tacos-coyoac%C3%A1...             1
#  3  https://www.yelp.com.mx/biz/osama-ciudad-cauce...             2
#  4  https://www.yelp.com.mx/biz/terraza-caucel-m%C...             1
#  5  https://www.yelp.com.mx/biz/tortas-la-familia-...             3
#
#                                            categories  rating  \
#  0  [{'alias': 'streetvendors', 'title': 'Puestos ...     4.5
#  1  [{'alias': 'yucatan', 'title': 'Cocina de Yuca...     5.0
#  2  [{'alias': 'streetvendors', 'title': 'Puestos ...     3.0
#  3  [{'alias': 'streetvendors', 'title': 'Puestos ...     3.5
#  4  [{'alias': 'fooddeliveryservices', 'title': 'S...     4.0
#  5            [{'alias': 'delis', 'title': 'Tortas'}]     3.5
#
#                                           coordinates transactions  \
#  0  {'latitude': 20.9966969857742, 'longitude': -8...           []
#  1  {'latitude': 20.9966520520368, 'longitude': -8...           []
#  2  {'latitude': 20.996601227401, 'longitude': -89...           []
#  3  {'latitude': 20.9866104, 'longitude': -89.7020...           []
#  4  {'latitude': 21.003883758081, 'longitude': -89...           []
#  5  {'latitude': 20.9957402420157, 'longitude': -8...           []
#
#                                              location          phone  \
#  0  {'address1': 'Av. 59 Fracc. Almendros (a lado ...
#  1  {'address1': 'Calle 59, Los Almendros, Cd. Cau...
#  2  {'address1': 'Av. 59 Fracc. Los Almendros (fte...
#  3  {'address1': 'Calle 70 entre 37', 'address2': ...
#  4  {'address1': 'Av. 80 Las Torres I, Cd. Caucel'...  +529993343603
#  5  {'address1': 'Calle 59 664 Ciudad Caucel', 'ad...
#
#       display_phone     distance price   tipo
#  0                   1898.669679   NaN  Tacos
#  1                   1908.664277   NaN  Tacos
#  2                   2494.131666   NaN  Tacos
#  3                   2571.922785   NaN  Tacos
#  4  01 999 334 3603  1910.636698   NaN  Tacos
#  5                   2596.126362     $  Tacos  ,                        id                                alias  \
#  0  oAHh2RzomP5aS7CmvtFvQw                    la-perrera-mérida
#  1  9PV0MFXwWv_2oM9AoOByHQ                vocho-s-burger-mérida
#  2  dJjx--AUVXt1ciMQvTcCxA                    maxi-carne-mérida
#  3  HYdjKvpJ5zoR2SCdBQA1mQ                  pollo-dorado-mérida
#  4  arPWgmLlIEELblyQgFbSIA  tortas-de-cochinita-de-la-59-mérida
#  5  SbQnTO6_bInB4BhHWSsflA                 los-compadres-mérida
#  6  Bgqj8kkHuBgpVgihyFdfYA      tortas-la-familia-ciudad-caucel
#  7  FgDFR8tCiae2MfYxoBWoNg                  osama-ciudad-caucel
#  8  7QhRp06Rj6yJPVQkxoCPNQ                     don-lauro-mérida
#  9  LqnKt_JAshmvXwf0MADOQw                 panuchos-dany-mérida
#
#                             name  \
#  0                    La Perrera
#  1                Vocho´s Burger
#  2                    Maxi Carne
#  3                  Pollo Dorado
#  4  Tortas de cochinita de la 59
#  5                 Los Compadres
#  6             Tortas La Familia
#  7                         Osama
#  8                     Don Lauro
#  9                 Panuchos Dany
#
#                                             image_url  is_closed  \
#  0  https://s3-media3.fl.yelpcdn.com/bphoto/1ruVd6...      False
#  1  https://s3-media3.fl.yelpcdn.com/bphoto/qzPMOj...      False
#  2  https://s3-media3.fl.yelpcdn.com/bphoto/zy92cu...      False
#  3  https://s3-media2.fl.yelpcdn.com/bphoto/M0CG1h...      False
#  4                                                         False
#  5  https://s3-media1.fl.yelpcdn.com/bphoto/2xGzYa...      False
#  6  https://s3-media3.fl.yelpcdn.com/bphoto/3UqfPd...      False
#  7  https://s3-media2.fl.yelpcdn.com/bphoto/3bo6X7...      False
#  8  https://s3-media1.fl.yelpcdn.com/bphoto/yB5gEJ...      False
#  9  https://s3-media2.fl.yelpcdn.com/bphoto/6RRjgM...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/la-perrera-m%C3%A9...             1
#  1  https://www.yelp.com.mx/biz/vocho-s-burger-m%C...             1
#  2  https://www.yelp.com.mx/biz/maxi-carne-m%C3%A9...             1
#  3  https://www.yelp.com.mx/biz/pollo-dorado-m%C3%...             2
#  4  https://www.yelp.com.mx/biz/tortas-de-cochinit...             1
#  5  https://www.yelp.com.mx/biz/los-compadres-m%C3...             1
#  6  https://www.yelp.com.mx/biz/tortas-la-familia-...             3
#  7  https://www.yelp.com.mx/biz/osama-ciudad-cauce...             2
#  8  https://www.yelp.com.mx/biz/don-lauro-m%C3%A9r...             2
#  9  https://www.yelp.com.mx/biz/panuchos-dany-m%C3...             1
#
#                                            categories  rating  \
#  0  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...     5.0
#  1    [{'alias': 'burgers', 'title': 'Hamburguesas'}]     4.0
#  2      [{'alias': 'butcher', 'title': 'Carnicería'}]     4.0
#  3  [{'alias': 'rotisserie_chicken', 'title': 'Pol...     3.5
#  4  [{'alias': 'yucatan', 'title': 'Cocina de Yuca...     5.0
#  5  [{'alias': 'mexican', 'title': 'Cocina mexican...     3.0
#  6            [{'alias': 'delis', 'title': 'Tortas'}]     3.5
#  7  [{'alias': 'streetvendors', 'title': 'Puestos ...     3.5
#  8  [{'alias': 'herbsandspices', 'title': 'Hierbas...     3.5
#  9  [{'alias': 'gourmet', 'title': 'Especialidades...     3.0
#
#                                           coordinates transactions  \
#  0  {'latitude': 21.0052448527215, 'longitude': -8...           []
#  1  {'latitude': 20.9962113273225, 'longitude': -8...           []
#  2  {'latitude': 20.9965518874432, 'longitude': -8...           []
#  3  {'latitude': 20.997233005354, 'longitude': -89...           []
#  4  {'latitude': 20.9966520520368, 'longitude': -8...           []
#  5  {'latitude': 20.9990055627461, 'longitude': -8...           []
#  6  {'latitude': 20.9957402420157, 'longitude': -8...           []
#  7  {'latitude': 20.9866104, 'longitude': -89.7020...           []
#  8  {'latitude': 20.9967121507606, 'longitude': -8...           []
#  9  {'latitude': 21.0029664800471, 'longitude': -8...           []
#
#                                              location          phone  \
#  0  {'address1': 'Av. 106 S/N', 'address2': 'Col. ...  +529999687527
#  1  {'address1': 'Av. 59 660 Los almendros, Cd. Ca...  +529993071768
#  2  {'address1': 'Av. 59 Los Almendros, Cd. Caucel...
#  3  {'address1': 'Av. 59 Los Almendros Cd. Caucel'...
#  4  {'address1': 'Calle 59, Los Almendros, Cd. Cau...
#  5  {'address1': 'Av. 88 Los Almendros, Cd. Caucel...
#  6  {'address1': 'Calle 59 664 Ciudad Caucel', 'ad...
#  7  {'address1': 'Calle 70 entre 37', 'address2': ...
#  8  {'address1': 'Calle 59 Los Almendros Cd. Cauce...
#  9  {'address1': 'Calle 106 Ciudad Caucel', 'addre...
#
#       display_phone     distance price   tipo
#  0  01 999 968 7527   285.954386   NaN  Carne
#  1  01 999 307 1768  2212.228918   NaN  Carne
#  2                   1918.960926   NaN  Carne
#  3                   1855.830784   NaN  Carne
#  4                   1908.664277   NaN  Carne
#  5                   1775.844713   NaN  Carne
#  6                   2596.126362     $  Carne
#  7                   2571.922785   NaN  Carne
#  8                   1911.743923   NaN  Carne
#  9                    485.582118    $$  Carne  ,                        id                                    alias  \
#  0  XDme8Qi0ifJdMBhdb9RzCw                  terraza-caucel-mérida-2
#  1  SbQnTO6_bInB4BhHWSsflA                     los-compadres-mérida
#  2  v_rAzbKcGvSAwr2YaVuJjg  tortas-y-tacos-de-asado-de-la-59-mérida
#  3  HYdjKvpJ5zoR2SCdBQA1mQ                      pollo-dorado-mérida
#  4  MAPLEfUihMQjf3tFbzRgHA                    los-almendros-yucatán
#
#                                 name  \
#  0                    Terraza Caucel
#  1                     Los Compadres
#  2  Tortas y tacos de Asado de la 59
#  3                      Pollo Dorado
#  4                     Los Almendros
#
#                                             image_url  is_closed  \
#  0  https://s3-media2.fl.yelpcdn.com/bphoto/WdfKUd...      False
#  1  https://s3-media1.fl.yelpcdn.com/bphoto/2xGzYa...      False
#  2  https://s3-media1.fl.yelpcdn.com/bphoto/69p5Lk...      False
#  3  https://s3-media2.fl.yelpcdn.com/bphoto/M0CG1h...      False
#  4  https://s3-media3.fl.yelpcdn.com/bphoto/DqeHhf...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/terraza-caucel-m%C...             1
#  1  https://www.yelp.com.mx/biz/los-compadres-m%C3...             1
#  2  https://www.yelp.com.mx/biz/tortas-y-tacos-de-...             2
#  3  https://www.yelp.com.mx/biz/pollo-dorado-m%C3%...             2
#  4  https://www.yelp.com.mx/biz/los-almendros-yuca...             1
#
#                                            categories  rating  \
#  0  [{'alias': 'fooddeliveryservices', 'title': 'S...     4.0
#  1  [{'alias': 'mexican', 'title': 'Cocina mexican...     3.0
#  2  [{'alias': 'streetvendors', 'title': 'Puestos ...     4.5
#  3  [{'alias': 'rotisserie_chicken', 'title': 'Pol...     3.5
#  4  [{'alias': 'fooddeliveryservices', 'title': 'S...     4.0
#
#                                           coordinates transactions  \
#  0  {'latitude': 21.003883758081, 'longitude': -89...           []
#  1  {'latitude': 20.9990055627461, 'longitude': -8...           []
#  2  {'latitude': 20.9966969857742, 'longitude': -8...           []
#  3  {'latitude': 20.997233005354, 'longitude': -89...           []
#  4  {'latitude': 20.9911252693568, 'longitude': -8...           []
#
#                                              location          phone  \
#  0  {'address1': 'Av. 80 Las Torres I, Cd. Caucel'...  +529993343603
#  1  {'address1': 'Av. 88 Los Almendros, Cd. Caucel...
#  2  {'address1': 'Av. 59 Fracc. Almendros (a lado ...
#  3  {'address1': 'Av. 59 Los Almendros Cd. Caucel'...
#  4  {'address1': 'Calle 88 685 B Los Almendros', '...
#
#       display_phone     distance price   tipo
#  0  01 999 334 3603  1910.636698   NaN  Asada
#  1                   1775.844713   NaN  Asada
#  2                   1898.669679   NaN  Asada
#  3                   1855.830784   NaN  Asada
#  4                   2220.453608    $$  Asada  , Empty DataFrame
#  Columns: [tipo]
#  Index: [],                        id                                alias  \
#  0  arPWgmLlIEELblyQgFbSIA  tortas-de-cochinita-de-la-59-mérida
#
#                             name image_url  is_closed  \
#  0  Tortas de cochinita de la 59                False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/tortas-de-cochinit...             1
#
#                                            categories  rating  \
#  0  [{'alias': 'yucatan', 'title': 'Cocina de Yuca...     5.0
#
#                                           coordinates transactions  \
#  0  {'latitude': 20.9966520520368, 'longitude': -8...           []
#
#                                              location phone display_phone  \
#  0  {'address1': 'Calle 59, Los Almendros, Cd. Cau...
#
#        distance       tipo
#  0  1908.664277  Cochinita  ,                        id                alias          name  \
#  0  HYdjKvpJ5zoR2SCdBQA1mQ  pollo-dorado-mérida  Pollo Dorado
#  1  HIeFOPyTI-45__9uuBGDQg    tunkuruchu-mérida    Tunkuruchu
#
#                                             image_url  is_closed  \
#  0  https://s3-media2.fl.yelpcdn.com/bphoto/M0CG1h...      False
#  1  https://s3-media2.fl.yelpcdn.com/bphoto/Uo7y6e...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/pollo-dorado-m%C3%...             2
#  1  https://www.yelp.com.mx/biz/tunkuruchu-m%C3%A9...             5
#
#                                            categories  rating  \
#  0  [{'alias': 'rotisserie_chicken', 'title': 'Pol...     3.5
#  1  [{'alias': 'pizza', 'title': 'Pizzería'}, {'al...     3.5
#
#                                           coordinates transactions  \
#  0  {'latitude': 20.997233005354, 'longitude': -89...           []
#  1  {'latitude': 20.9960310304735, 'longitude': -8...           []
#
#                                              location          phone  \
#  0  {'address1': 'Av. 59 Los Almendros Cd. Caucel'...
#  1  {'address1': 'Av. 59', 'address2': 'Ciudad Cau...  +529993308583
#
#       display_phone     distance   tipo
#  0                   1855.830784  Pollo
#  1  01 999 330 8583  2221.344951  Pollo  ,                        id                                    alias  \
#  0  arPWgmLlIEELblyQgFbSIA      tortas-de-cochinita-de-la-59-mérida
#  1  v_rAzbKcGvSAwr2YaVuJjg  tortas-y-tacos-de-asado-de-la-59-mérida
#  2  XDme8Qi0ifJdMBhdb9RzCw                  terraza-caucel-mérida-2
#  3  Bgqj8kkHuBgpVgihyFdfYA          tortas-la-familia-ciudad-caucel
#  4  X80EZXhGzPALDFDBlcW9pw                   bocaditos-y-mas-mérida
#  5  uIzLqC0QZaARgOehohKb8g                    tacos-coyoacán-mérida
#
#                                 name  \
#  0      Tortas de cochinita de la 59
#  1  Tortas y tacos de Asado de la 59
#  2                    Terraza Caucel
#  3                 Tortas La Familia
#  4                   Bocaditos y mas
#  5                    Tacos Coyoacán
#
#                                             image_url  is_closed  \
#  0                                                         False
#  1  https://s3-media1.fl.yelpcdn.com/bphoto/69p5Lk...      False
#  2  https://s3-media2.fl.yelpcdn.com/bphoto/WdfKUd...      False
#  3  https://s3-media3.fl.yelpcdn.com/bphoto/3UqfPd...      False
#  4  https://s3-media4.fl.yelpcdn.com/bphoto/DEr_Dk...      False
#  5                                                         False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/tortas-de-cochinit...             1
#  1  https://www.yelp.com.mx/biz/tortas-y-tacos-de-...             2
#  2  https://www.yelp.com.mx/biz/terraza-caucel-m%C...             1
#  3  https://www.yelp.com.mx/biz/tortas-la-familia-...             3
#  4  https://www.yelp.com.mx/biz/bocaditos-y-mas-m%...             1
#  5  https://www.yelp.com.mx/biz/tacos-coyoac%C3%A1...             1
#
#                                            categories  rating  \
#  0  [{'alias': 'yucatan', 'title': 'Cocina de Yuca...     5.0
#  1  [{'alias': 'streetvendors', 'title': 'Puestos ...     4.5
#  2  [{'alias': 'fooddeliveryservices', 'title': 'S...     4.0
#  3            [{'alias': 'delis', 'title': 'Tortas'}]     3.5
#  4  [{'alias': 'desserts', 'title': 'Postres'}, {'...     4.0
#  5  [{'alias': 'streetvendors', 'title': 'Puestos ...     3.0
#
#                                           coordinates transactions  \
#  0  {'latitude': 20.9966520520368, 'longitude': -8...           []
#  1  {'latitude': 20.9966969857742, 'longitude': -8...           []
#  2  {'latitude': 21.003883758081, 'longitude': -89...           []
#  3  {'latitude': 20.9957402420157, 'longitude': -8...           []
#  4  {'latitude': 20.9863748145045, 'longitude': -8...           []
#  5  {'latitude': 20.996601227401, 'longitude': -89...           []
#
#                                              location          phone  \
#  0  {'address1': 'Calle 59, Los Almendros, Cd. Cau...
#  1  {'address1': 'Av. 59 Fracc. Almendros (a lado ...
#  2  {'address1': 'Av. 80 Las Torres I, Cd. Caucel'...  +529993343603
#  3  {'address1': 'Calle 59 664 Ciudad Caucel', 'ad...
#  4  {'address1': 'Calle 60 861 Herradura III Cd. C...  +529991275918
#  5  {'address1': 'Av. 59 Fracc. Los Almendros (fte...
#
#       display_phone     distance price       tipo
#  0                   1908.664277   NaN  Desayunos
#  1                   1898.669679   NaN  Desayunos
#  2  01 999 334 3603  1910.636698   NaN  Desayunos
#  3                   2596.126362     $  Desayunos
#  4  01 999 127 5918  3588.975045   NaN  Desayunos
#  5                   2494.131666   NaN  Desayunos  ,                        id                                    alias  \
#  0  v_rAzbKcGvSAwr2YaVuJjg  tortas-y-tacos-de-asado-de-la-59-mérida
#  1  Bgqj8kkHuBgpVgihyFdfYA          tortas-la-familia-ciudad-caucel
#  2  arPWgmLlIEELblyQgFbSIA      tortas-de-cochinita-de-la-59-mérida
#  3  SbQnTO6_bInB4BhHWSsflA                     los-compadres-mérida
#
#                                 name  \
#  0  Tortas y tacos de Asado de la 59
#  1                 Tortas La Familia
#  2      Tortas de cochinita de la 59
#  3                     Los Compadres
#
#                                             image_url  is_closed  \
#  0  https://s3-media1.fl.yelpcdn.com/bphoto/69p5Lk...      False
#  1  https://s3-media3.fl.yelpcdn.com/bphoto/3UqfPd...      False
#  2                                                         False
#  3  https://s3-media1.fl.yelpcdn.com/bphoto/2xGzYa...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/tortas-y-tacos-de-...             2
#  1  https://www.yelp.com.mx/biz/tortas-la-familia-...             3
#  2  https://www.yelp.com.mx/biz/tortas-de-cochinit...             1
#  3  https://www.yelp.com.mx/biz/los-compadres-m%C3...             1
#
#                                            categories  rating  \
#  0  [{'alias': 'streetvendors', 'title': 'Puestos ...     4.5
#  1            [{'alias': 'delis', 'title': 'Tortas'}]     3.5
#  2  [{'alias': 'yucatan', 'title': 'Cocina de Yuca...     5.0
#  3  [{'alias': 'mexican', 'title': 'Cocina mexican...     3.0
#
#                                           coordinates transactions  \
#  0  {'latitude': 20.9966969857742, 'longitude': -8...           []
#  1  {'latitude': 20.9957402420157, 'longitude': -8...           []
#  2  {'latitude': 20.9966520520368, 'longitude': -8...           []
#  3  {'latitude': 20.9990055627461, 'longitude': -8...           []
#
#                                              location phone display_phone  \
#  0  {'address1': 'Av. 59 Fracc. Almendros (a lado ...
#  1  {'address1': 'Calle 59 664 Ciudad Caucel', 'ad...
#  2  {'address1': 'Calle 59, Los Almendros, Cd. Cau...
#  3  {'address1': 'Av. 88 Los Almendros, Cd. Caucel...
#
#        distance price    tipo
#  0  1898.669679   NaN  Tortas
#  1  2596.126362     $  Tortas
#  2  1908.664277   NaN  Tortas
#  3  1775.844713   NaN  Tortas  , Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [],                        id                    alias            name  \
#  0  XDme8Qi0ifJdMBhdb9RzCw  terraza-caucel-mérida-2  Terraza Caucel
#  1  haMcI5xZ5kDVY4R7iWBirw       el-almendro-mérida     El Almendro
#
#                                             image_url  is_closed  \
#  0  https://s3-media2.fl.yelpcdn.com/bphoto/WdfKUd...      False
#  1  https://s3-media1.fl.yelpcdn.com/bphoto/Kxi32N...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/terraza-caucel-m%C...             1
#  1  https://www.yelp.com.mx/biz/el-almendro-m%C3%A...             1
#
#                                            categories  rating  \
#  0  [{'alias': 'fooddeliveryservices', 'title': 'S...     4.0
#  1  [{'alias': 'gourmet', 'title': 'Especialidades...     3.0
#
#                                           coordinates transactions  \
#  0  {'latitude': 21.003883758081, 'longitude': -89...           []
#  1  {'latitude': 20.997793923653, 'longitude': -89...           []
#
#                                              location          phone  \
#  0  {'address1': 'Av. 80 Las Torres I, Cd. Caucel'...  +529993343603
#  1  {'address1': 'Calle 88 Los Almendros, Cd. Cauc...
#
#       display_phone     distance price       tipo
#  0  01 999 334 3603  1910.636698   NaN  Empanadas
#  1                   1828.164126   $$$  Empanadas  , Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [],                        id             alias        name  \
#  0  -Nvh7oy7_U9C-JGW8EiF0A   papitzza-mérida    Papitzza
#  1  PojQHpVK8nFGLcn8w7GwKw  mr-panini-mérida  Mr. Panini
#
#                                             image_url  is_closed  \
#  0  https://s3-media1.fl.yelpcdn.com/bphoto/cBOU2Y...      False
#  1                                                         False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/papitzza-m%C3%A9ri...             1
#  1  https://www.yelp.com.mx/biz/mr-panini-m%C3%A9r...             3
#
#                                            categories  rating  \
#  0          [{'alias': 'pizza', 'title': 'Pizzería'}]     3.0
#  1  [{'alias': 'creperies', 'title': 'Creperías'},...     3.5
#
#                                           coordinates transactions  \
#  0  {'latitude': 20.9965518874432, 'longitude': -8...           []
#  1  {'latitude': 20.9969926111521, 'longitude': -8...           []
#
#                                              location          phone  \
#  0  {'address1': 'Av. 59 Los Almendros, Cd. Caucel...  +529993127295
#  1  {'address1': 'Av. 59, Los Almendros,Cd. Caucel...
#
#       display_phone     distance       tipo
#  0  01 999 312 7295  1929.592345  Baguettes
#  1                   2013.738441  Baguettes  , Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [],                        id              alias        name  \
#  0  oAHh2RzomP5aS7CmvtFvQw  la-perrera-mérida  La Perrera
#
#                                             image_url  is_closed  \
#  0  https://s3-media3.fl.yelpcdn.com/bphoto/1ruVd6...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/la-perrera-m%C3%A9...             1
#
#                                            categories  rating  \
#  0  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...     5.0
#
#                                           coordinates transactions  \
#  0  {'latitude': 21.0052448527215, 'longitude': -8...           []
#
#                                              location          phone  \
#  0  {'address1': 'Av. 106 S/N', 'address2': 'Col. ...  +529999687527
#
#       display_phone    distance       tipo
#  0  01 999 968 7527  285.954386  Arrachera  ,                        id                 alias           name  \
#  0  oAHh2RzomP5aS7CmvtFvQw     la-perrera-mérida     La Perrera
#  1  SbQnTO6_bInB4BhHWSsflA  los-compadres-mérida  Los Compadres
#
#                                             image_url  is_closed  \
#  0  https://s3-media3.fl.yelpcdn.com/bphoto/1ruVd6...      False
#  1  https://s3-media1.fl.yelpcdn.com/bphoto/2xGzYa...      False
#
#                                                   url  review_count  \
#  0  https://www.yelp.com.mx/biz/la-perrera-m%C3%A9...             1
#  1  https://www.yelp.com.mx/biz/los-compadres-m%C3...             1
#
#                                            categories  rating  \
#  0  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...     5.0
#  1  [{'alias': 'mexican', 'title': 'Cocina mexican...     3.0
#
#                                           coordinates transactions  \
#  0  {'latitude': 21.0052448527215, 'longitude': -8...           []
#  1  {'latitude': 20.9990055627461, 'longitude': -8...           []
#
#                                              location          phone  \
#  0  {'address1': 'Av. 106 S/N', 'address2': 'Col. ...  +529999687527
#  1  {'address1': 'Av. 88 Los Almendros, Cd. Caucel...
#
#       display_phone     distance    tipo
#  0  01 999 968 7527   285.954386  Pastor
#  1                   1775.844713  Pastor  , Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: [], Empty DataFrame
#  Columns: [tipo]
#  Index: []]

# %%
lugares = pd.concat(yelp_search, axis=0, sort=False)
print(lugares.shape)
lugares.reset_index(inplace=True)
lugares
# Out:
# (55, 17)
#     index       tipo                      id                           alias  \
# 0       0      Pizza  KeRV9bkIUlV_2ROX3XbAeg                  baleros-mérida
# 1       1      Pizza  -Nvh7oy7_U9C-JGW8EiF0A                 papitzza-mérida
# 2       2      Pizza  bO9dWhFxdQ-zs0mfib7vrw        pizzeria-bernardi-mérida
# 3       3      Pizza  svFqSohn16FFhfIfzlKGFw        l-ora-della-pizza-mérida
# 4       4      Pizza  XSemDWcz5HISvGnNB80FLQ  messina-s-caucel-ciudad-caucel
# ..    ...        ...                     ...                             ...
# 50      0  Baguettes  -Nvh7oy7_U9C-JGW8EiF0A                 papitzza-mérida
# 51      1  Baguettes  PojQHpVK8nFGLcn8w7GwKw                mr-panini-mérida
# 52      0  Arrachera  oAHh2RzomP5aS7CmvtFvQw               la-perrera-mérida
# 53      0     Pastor  oAHh2RzomP5aS7CmvtFvQw               la-perrera-mérida
# 54      1     Pastor  SbQnTO6_bInB4BhHWSsflA            los-compadres-mérida
#
#                  name                                          image_url  \
# 0            Balero's  https://s3-media3.fl.yelpcdn.com/bphoto/w3Ic5J...
# 1            Papitzza  https://s3-media1.fl.yelpcdn.com/bphoto/cBOU2Y...
# 2   Pizzeria Bernardi  https://s3-media4.fl.yelpcdn.com/bphoto/n5zzjS...
# 3   L'ora della Pizza  https://s3-media3.fl.yelpcdn.com/bphoto/NlVuwP...
# 4    Messina´s Caucel
# ..                ...                                                ...
# 50           Papitzza  https://s3-media1.fl.yelpcdn.com/bphoto/cBOU2Y...
# 51         Mr. Panini
# 52         La Perrera  https://s3-media3.fl.yelpcdn.com/bphoto/1ruVd6...
# 53         La Perrera  https://s3-media3.fl.yelpcdn.com/bphoto/1ruVd6...
# 54      Los Compadres  https://s3-media1.fl.yelpcdn.com/bphoto/2xGzYa...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com.mx/biz/baleros-m%C3%A9rid...          10.0
# 1      False  https://www.yelp.com.mx/biz/papitzza-m%C3%A9ri...           1.0
# 2      False  https://www.yelp.com.mx/biz/pizzeria-bernardi-...           2.0
# 3      False  https://www.yelp.com.mx/biz/l-ora-della-pizza-...           5.0
# 4      False  https://www.yelp.com.mx/biz/messina-s-caucel-c...           1.0
# ..       ...                                                ...           ...
# 50     False  https://www.yelp.com.mx/biz/papitzza-m%C3%A9ri...           1.0
# 51     False  https://www.yelp.com.mx/biz/mr-panini-m%C3%A9r...           3.0
# 52     False  https://www.yelp.com.mx/biz/la-perrera-m%C3%A9...           1.0
# 53     False  https://www.yelp.com.mx/biz/la-perrera-m%C3%A9...           1.0
# 54     False  https://www.yelp.com.mx/biz/los-compadres-m%C3...           1.0
#
#                                            categories  rating  \
# 0           [{'alias': 'pizza', 'title': 'Pizzería'}]     3.5
# 1           [{'alias': 'pizza', 'title': 'Pizzería'}]     3.0
# 2           [{'alias': 'pizza', 'title': 'Pizzería'}]     4.5
# 3   [{'alias': 'pizza', 'title': 'Pizzería'}, {'al...     4.0
# 4           [{'alias': 'pizza', 'title': 'Pizzería'}]     4.0
# ..                                                ...     ...
# 50          [{'alias': 'pizza', 'title': 'Pizzería'}]     3.0
# 51  [{'alias': 'creperies', 'title': 'Creperías'},...     3.5
# 52  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...     5.0
# 53  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...     5.0
# 54  [{'alias': 'mexican', 'title': 'Cocina mexican...     3.0
#
#                                           coordinates transactions price  \
# 0   {'latitude': 21.0017109105729, 'longitude': -8...           []     $
# 1   {'latitude': 20.9965518874432, 'longitude': -8...           []   NaN
# 2   {'latitude': 21.0002995, 'longitude': -89.5464...           []   NaN
# 3   {'latitude': 20.9934759206305, 'longitude': -8...           []    $$
# 4   {'latitude': 20.9866104, 'longitude': -89.7020...           []   NaN
# ..                                                ...          ...   ...
# 50  {'latitude': 20.9965518874432, 'longitude': -8...           []   NaN
# 51  {'latitude': 20.9969926111521, 'longitude': -8...           []   NaN
# 52  {'latitude': 21.0052448527215, 'longitude': -8...           []   NaN
# 53  {'latitude': 21.0052448527215, 'longitude': -8...           []   NaN
# 54  {'latitude': 20.9990055627461, 'longitude': -8...           []   NaN
#
#                                              location          phone  \
# 0   {'address1': 'Av 88 695 Sol Caucel', 'address2...  +529999409595
# 1   {'address1': 'Av. 59 Los Almendros, Cd. Caucel...  +529993127295
# 2   {'address1': 'Calle 35', 'address2': 'por 48 A...  +529999889059
# 3   {'address1': 'Av. 88 Los Almendros, Cd. Caucel...  +529992678237
# 4   {'address1': 'Calle 70 no. 635', 'address2': '...
# ..                                                ...            ...
# 50  {'address1': 'Av. 59 Los Almendros, Cd. Caucel...  +529993127295
# 51  {'address1': 'Av. 59, Los Almendros,Cd. Caucel...
# 52  {'address1': 'Av. 106 S/N', 'address2': 'Col. ...  +529999687527
# 53  {'address1': 'Av. 106 S/N', 'address2': 'Col. ...  +529999687527
# 54  {'address1': 'Av. 88 Los Almendros, Cd. Caucel...
#
#       display_phone     distance
# 0   01 999 940 9595  1695.884969
# 1   01 999 312 7295  1929.592345
# 2   01 999 988 9059   333.746571
# 3   01 999 267 8237  2054.603163
# 4                    2569.961573
# ..              ...          ...
# 50  01 999 312 7295  1929.592345
# 51                   2013.738441
# 52  01 999 968 7527   285.954386
# 53  01 999 968 7527   285.954386
# 54                   1775.844713
#
# [55 rows x 18 columns]

# %%
lugares.tipo.value_counts()
# Out:
# Carne           10
# Pizza            7
# Tacos            6
# Desayunos        6
# Asada            5
# Tortas           4
# Hamburguesas     4
# Pastor           2
# Pollo            2
# Hot Dogs         2
# Baguettes        2
# Empanadas        2
# Cochinita        1
# Sushi            1
# Arrachera        1
# Name: tipo, dtype: int64

# %%
#lugares.reset_index(inplace=True)

# %% [markdown]
# ### La información más relevante que extraemos de Yelp es el 'rating' por giro de comida, por lo que de los resultados sacamos promedios basados en su giro.

# %%
ratings = dict(lugares.tipo.value_counts())
for comida in inegi_results:
    ratings[comida] = lugares[lugares.tipo == comida]['rating'].mean()
ratings
# Out:
# {'Carne': 3.8,
#  'Pizza': 3.7142857142857144,
#  'Tacos': 3.9166666666666665,
#  'Desayunos': 4.0,
#  'Asada': 3.8,
#  'Tortas': 4.0,
#  'Hamburguesas': 4.75,
#  'Pastor': 4.0,
#  'Pollo': 3.5,
#  'Hot Dogs': 5.0,
#  'Baguettes': 3.25,
#  'Empanadas': 3.5,
#  'Cochinita': 5.0,
#  'Sushi': 3.5,
#  'Arrachera': 5.0,
#  'Cocina Económica': nan,
#  'Antojitos': nan,
#  'Tamales': nan,
#  'Mariscos': nan,
#  'Pescado': nan,
#  'Panuchos': nan,
#  'Mondongo': nan,
#  'Menudo': nan,
#  'Memelas': nan,
#  'Chicharrón': nan,
#  'Gorditas': nan,
#  'Costillas': nan,
#  'Carnitas': nan,
#  'Doraditas': nan,
#  'Parrilla': nan,
#  'Huaraches': nan,
#  'Rosticería': nan,
#  'China': nan,
#  'Yucateca': nan,
#  'Tabasqueña': nan,
#  'Birria': nan,
#  'Barbacoa': nan,
#  'Carnero': nan,
#  'Pozole': nan,
#  'Enchiladas': nan,
#  'Chilaquiles': nan}

# %%
yf = pd.concat(yelp_search)
yf.drop(columns = ['alias', 'display_phone', 'location', 'id', 'image_url', 'is_closed', 'phone', 'transactions', 'url'], inplace=True)
yf.reset_index(inplace=True)
yf.head()
# Out:
# /home/linuxbrew/.linuxbrew/Cellar/jupyterlab/1.2.4/libexec/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    index                                         categories  \
# 0      0          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 1      1          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 2      2          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 3      3  [{'alias': 'pizza', 'title': 'Pizzería'}, {'al...
# 4      4          [{'alias': 'pizza', 'title': 'Pizzería'}]
#
#                                          coordinates     distance  \
# 0  {'latitude': 21.0017109105729, 'longitude': -8...  1695.884969
# 1  {'latitude': 20.9965518874432, 'longitude': -8...  1929.592345
# 2  {'latitude': 21.0002995, 'longitude': -89.5464...   333.746571
# 3  {'latitude': 20.9934759206305, 'longitude': -8...  2054.603163
# 4  {'latitude': 20.9866104, 'longitude': -89.7020...  2569.961573
#
#                 name price  rating  review_count   tipo
# 0           Balero's     $     3.5          10.0  Pizza
# 1           Papitzza   NaN     3.0           1.0  Pizza
# 2  Pizzeria Bernardi   NaN     4.5           2.0  Pizza
# 3  L'ora della Pizza    $$     4.0           5.0  Pizza
# 4   Messina´s Caucel   NaN     4.0           1.0  Pizza

# %%
df['YelpRating'] = yf.groupby('tipo').mean().rating
df
# Out:
#                   InegiCount  GoogleTrend      slope  YelpRating
# Index
# Cocina Económica        1409          100   5.914383         NaN
# Antojitos               1030           33  20.597907         NaN
# Pizza                    309          100  37.696463    3.714286
# Hamburguesas             149           53  10.257059    4.750000
# Hot Dogs                  36           28  43.804627    5.000000
# ...                      ...          ...        ...         ...
# Barbacoa                  15           31  24.722635         NaN
# Carnero                    1          100  28.981757         NaN
# Pozole                    12           25  13.468936         NaN
# Enchiladas                 1           42  59.527409         NaN
# Chilaquiles                0           77  38.677660         NaN
#
# [41 rows x 4 columns]

# %% [markdown]
# # Score

# %%
#df['score'] = df.GoogleTrend/100 - df.YelpRating/5 - df.InegiCount/df.InegiCount.max()
#df['score'] = 0.05*df.GoogleTrend/df.YelpRating - df.InegiCount/df.InegiCount.max() + 0.5*df.slope/df.slope.max()
df['score'] = df.GoogleTrend/100 + df.slope/df.slope.max() - df.YelpRating/5 - df.InegiCount/df.InegiCount.max()
df.sort_values(by='score', ascending=False)
# Out:
#              InegiCount  GoogleTrend      slope  YelpRating     score
# Index
# Baguettes             6          100  46.149455    3.250000  1.121006
# Desayunos            89           77  58.583525    4.000000  0.890978
# Pollo               230           78  56.130091    3.500000  0.859692
# Pastor               22           92  44.895255    4.000000  0.858581
# Pizza               309          100  37.696463    3.714286  0.671101
# ...                 ...          ...        ...         ...       ...
# Barbacoa             15           31  24.722635         NaN       NaN
# Carnero               1          100  28.981757         NaN       NaN
# Pozole               12           25  13.468936         NaN       NaN
# Enchiladas            1           42  59.527409         NaN       NaN
# Chilaquiles           0           77  38.677660         NaN       NaN
#
# [41 rows x 5 columns]

# %%
df.describe()
# Out:
#         InegiCount  GoogleTrend      slope  YelpRating      score
# count    41.000000    41.000000  41.000000   15.000000  15.000000
# mean    129.170732    55.268293  30.193535    4.048730   0.315604
# std     280.747743    31.014532  15.141284    0.598090   0.506652
# min       0.000000     0.000000   4.320778    3.250000  -0.398086
# 25%       7.000000    30.000000  19.913351    3.607143  -0.062680
# 50%      27.000000    53.000000  29.294430    3.916667   0.313742
# 75%      91.000000    80.000000  43.804627    4.375000   0.764841
# max    1409.000000   100.000000  59.527409    5.000000   1.121006

# %% [markdown]
# ## Yelp Locations Dataframe

# %%
from pandas.io.json import json_normalize
yf.head()
# Out:
#    index                                         categories  \
# 0      0          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 1      1          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 2      2          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 3      3  [{'alias': 'pizza', 'title': 'Pizzería'}, {'al...
# 4      4          [{'alias': 'pizza', 'title': 'Pizzería'}]
#
#                                          coordinates     distance  \
# 0  {'latitude': 21.0017109105729, 'longitude': -8...  1695.884969
# 1  {'latitude': 20.9965518874432, 'longitude': -8...  1929.592345
# 2  {'latitude': 21.0002995, 'longitude': -89.5464...   333.746571
# 3  {'latitude': 20.9934759206305, 'longitude': -8...  2054.603163
# 4  {'latitude': 20.9866104, 'longitude': -89.7020...  2569.961573
#
#                 name price  rating  review_count   tipo
# 0           Balero's     $     3.5          10.0  Pizza
# 1           Papitzza   NaN     3.0           1.0  Pizza
# 2  Pizzeria Bernardi   NaN     4.5           2.0  Pizza
# 3  L'ora della Pizza    $$     4.0           5.0  Pizza
# 4   Messina´s Caucel   NaN     4.0           1.0  Pizza

# %%
json_normalize(yf.coordinates)
# Out:
#      latitude  longitude
# 0   21.001711 -89.702879
# 1   20.996552 -89.703376
# 2   21.000300 -89.546471
# 3   20.993476 -89.704745
# 4   20.986610 -89.702049
# ..        ...        ...
# 50  20.996552 -89.703376
# 51  20.996993 -89.702046
# 52  21.005245 -89.716213
# 53  21.005245 -89.716213
# 54  20.999006 -89.703401
#
# [55 rows x 2 columns]

# %%
#yf.reset_index()
yf[['latitude', 'longitude']] = json_normalize(yf.coordinates)
#yf.drop(columns=['coordinates'], inplace=True)
yf.head()
# Out:
#    index                                         categories  \
# 0      0          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 1      1          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 2      2          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 3      3  [{'alias': 'pizza', 'title': 'Pizzería'}, {'al...
# 4      4          [{'alias': 'pizza', 'title': 'Pizzería'}]
#
#                                          coordinates     distance  \
# 0  {'latitude': 21.0017109105729, 'longitude': -8...  1695.884969
# 1  {'latitude': 20.9965518874432, 'longitude': -8...  1929.592345
# 2  {'latitude': 21.0002995, 'longitude': -89.5464...   333.746571
# 3  {'latitude': 20.9934759206305, 'longitude': -8...  2054.603163
# 4  {'latitude': 20.9866104, 'longitude': -89.7020...  2569.961573
#
#                 name price  rating  review_count   tipo   latitude  longitude
# 0           Balero's     $     3.5          10.0  Pizza  21.001711 -89.702879
# 1           Papitzza   NaN     3.0           1.0  Pizza  20.996552 -89.703376
# 2  Pizzeria Bernardi   NaN     4.5           2.0  Pizza  21.000300 -89.546471
# 3  L'ora della Pizza    $$     4.0           5.0  Pizza  20.993476 -89.704745
# 4   Messina´s Caucel   NaN     4.0           1.0  Pizza  20.986610 -89.702049

# %%
yf[yf.tipo=='Arrachera']
# Out:
#     index                                         categories  \
# 52      0  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...
#
#                                           coordinates    distance        name  \
# 52  {'latitude': 21.0052448527215, 'longitude': -8...  285.954386  La Perrera
#
#    price  rating  review_count       tipo   latitude  longitude
# 52   NaN     5.0           1.0  Arrachera  21.005245 -89.716213

# %%
top_types = df.sort_values(by='score', ascending=False).head().index

top_yf_locs = {}
for top in top_types:
    print(top)
    print(yf[yf.tipo==top][['latitude', 'longitude']])
    top_yf_locs[top] = yf[yf.tipo==top][['latitude', 'longitude']].head().values
    
top_yf_locs
# Out:
# Baguettes
#      latitude  longitude
# 50  20.996552 -89.703376
# 51  20.996993 -89.702046
# Desayunos
#      latitude  longitude
# 38  20.996652 -89.703548
# 39  20.996697 -89.703632
# 40  21.003884 -89.700093
# 41  20.995740 -89.696301
# 42  20.986375 -89.691628
# 43  20.996601 -89.696920
# Pollo
#      latitude  longitude
# 36  20.997233 -89.703720
# 37  20.996031 -89.700329
# Pastor
#      latitude  longitude
# 53  21.005245 -89.716213
# 54  20.999006 -89.703401
# Pizza
#     latitude  longitude
# 0  21.001711 -89.702879
# 1  20.996552 -89.703376
# 2  21.000300 -89.546471
# 3  20.993476 -89.704745
# 4  20.986610 -89.702049
# 5  20.996031 -89.700329
# 6  20.997487 -89.704042
# {'Baguettes': array([[ 20.99655189, -89.70337644],
#         [ 20.99699261, -89.70204607]]),
#  'Desayunos': array([[ 20.99665205, -89.70354811],
#         [ 20.99669699, -89.70363246],
#         [ 21.00388376, -89.70009342],
#         [ 20.99574024, -89.69630095],
#         [ 20.98637481, -89.69162837]]),
#  'Pollo': array([[ 20.99723301, -89.70371977],
#         [ 20.99603103, -89.70032946]]),
#  'Pastor': array([[ 21.00524485, -89.71621256],
#         [ 20.99900556, -89.70340092]]),
#  'Pizza': array([[ 21.00171091, -89.70287864],
#         [ 20.99655189, -89.70337644],
#         [ 21.0002995 , -89.5464706 ],
#         [ 20.99347592, -89.70474495],
#         [ 20.9866104 , -89.7020493 ]])}

# %%
top_yf = pd.DataFrame(columns = yf.columns)
for top in top_types:
    print(top)
    #print(yf[yf.tipo==top])
    top_yf = pd.concat([top_yf, yf[yf.tipo==top]])
    
top_yf
# Out:
# Baguettes
# Desayunos
# Pollo
# Pastor
# Pizza
#    index                                         categories  \
# 50     0          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 51     1  [{'alias': 'creperies', 'title': 'Creperías'},...
# 38     0  [{'alias': 'yucatan', 'title': 'Cocina de Yuca...
# 39     1  [{'alias': 'streetvendors', 'title': 'Puestos ...
# 40     2  [{'alias': 'fooddeliveryservices', 'title': 'S...
# 41     3            [{'alias': 'delis', 'title': 'Tortas'}]
# 42     4  [{'alias': 'desserts', 'title': 'Postres'}, {'...
# 43     5  [{'alias': 'streetvendors', 'title': 'Puestos ...
# 36     0  [{'alias': 'rotisserie_chicken', 'title': 'Pol...
# 37     1  [{'alias': 'pizza', 'title': 'Pizzería'}, {'al...
# 53     0  [{'alias': 'hotdog', 'title': 'Hot dogs'}, {'a...
# 54     1  [{'alias': 'mexican', 'title': 'Cocina mexican...
# 0      0          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 1      1          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 2      2          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 3      3  [{'alias': 'pizza', 'title': 'Pizzería'}, {'al...
# 4      4          [{'alias': 'pizza', 'title': 'Pizzería'}]
# 5      5  [{'alias': 'pizza', 'title': 'Pizzería'}, {'al...
# 6      6                                                 []
#
#                                           coordinates     distance  \
# 50  {'latitude': 20.9965518874432, 'longitude': -8...  1929.592345
# 51  {'latitude': 20.9969926111521, 'longitude': -8...  2013.738441
# 38  {'latitude': 20.9966520520368, 'longitude': -8...  1908.664277
# 39  {'latitude': 20.9966969857742, 'longitude': -8...  1898.669679
# 40  {'latitude': 21.003883758081, 'longitude': -89...  1910.636698
# 41  {'latitude': 20.9957402420157, 'longitude': -8...  2596.126362
# 42  {'latitude': 20.9863748145045, 'longitude': -8...  3588.975045
# 43  {'latitude': 20.996601227401, 'longitude': -89...  2494.131666
# 36  {'latitude': 20.997233005354, 'longitude': -89...  1855.830784
# 37  {'latitude': 20.9960310304735, 'longitude': -8...  2221.344951
# 53  {'latitude': 21.0052448527215, 'longitude': -8...   285.954386
# 54  {'latitude': 20.9990055627461, 'longitude': -8...  1775.844713
# 0   {'latitude': 21.0017109105729, 'longitude': -8...  1695.884969
# 1   {'latitude': 20.9965518874432, 'longitude': -8...  1929.592345
# 2   {'latitude': 21.0002995, 'longitude': -89.5464...   333.746571
# 3   {'latitude': 20.9934759206305, 'longitude': -8...  2054.603163
# 4   {'latitude': 20.9866104, 'longitude': -89.7020...  2569.961573
# 5   {'latitude': 20.9960310304735, 'longitude': -8...  2221.344951
# 6   {'latitude': 20.9974865338512, 'longitude': -8...  1812.208710
#
#                                 name price  rating  review_count       tipo  \
# 50                          Papitzza   NaN     3.0           1.0  Baguettes
# 51                        Mr. Panini   NaN     3.5           3.0  Baguettes
# 38      Tortas de cochinita de la 59   NaN     5.0           1.0  Desayunos
# 39  Tortas y tacos de Asado de la 59   NaN     4.5           2.0  Desayunos
# 40                    Terraza Caucel   NaN     4.0           1.0  Desayunos
# 41                 Tortas La Familia     $     3.5           3.0  Desayunos
# 42                   Bocaditos y mas   NaN     4.0           1.0  Desayunos
# 43                    Tacos Coyoacán   NaN     3.0           1.0  Desayunos
# 36                      Pollo Dorado   NaN     3.5           2.0      Pollo
# 37                        Tunkuruchu   NaN     3.5           5.0      Pollo
# 53                        La Perrera   NaN     5.0           1.0     Pastor
# 54                     Los Compadres   NaN     3.0           1.0     Pastor
# 0                           Balero's     $     3.5          10.0      Pizza
# 1                           Papitzza   NaN     3.0           1.0      Pizza
# 2                  Pizzeria Bernardi   NaN     4.5           2.0      Pizza
# 3                  L'ora della Pizza    $$     4.0           5.0      Pizza
# 4                   Messina´s Caucel   NaN     4.0           1.0      Pizza
# 5                         Tunkuruchu   NaN     3.5           5.0      Pizza
# 6          Luigis Pizza & Suchito-Go   NaN     3.5           2.0      Pizza
#
#      latitude  longitude
# 50  20.996552 -89.703376
# 51  20.996993 -89.702046
# 38  20.996652 -89.703548
# 39  20.996697 -89.703632
# 40  21.003884 -89.700093
# 41  20.995740 -89.696301
# 42  20.986375 -89.691628
# 43  20.996601 -89.696920
# 36  20.997233 -89.703720
# 37  20.996031 -89.700329
# 53  21.005245 -89.716213
# 54  20.999006 -89.703401
# 0   21.001711 -89.702879
# 1   20.996552 -89.703376
# 2   21.000300 -89.546471
# 3   20.993476 -89.704745
# 4   20.986610 -89.702049
# 5   20.996031 -89.700329
# 6   20.997487 -89.704042

# %% [markdown]
# # Foursquare

# %%
import foursquare

client = foursquare.Foursquare(client_id='HVOBXQ5NMUK2AZBCBRSXIBBIFTI1PXKYYMXL2ZG0CIPOTULA', client_secret='BIKGFRQS2FVUM0VN51R5FMIGCRTUYG31BU5IW24CBHSSDNIO')

# %%
fs_results = {}
for comida in top_yf_locs.keys():
    print(comida)
    fs_results[comida] = client.venues.search(params={'query': comida, 'intent':'checkin', 'll': '21.007038700000003, -89.71818643311036', 'radius':3000, 'limit':10})
    
fs_results
# Out:
# Baguettes
# Desayunos
# Pollo
# Pastor
# Pizza
# {'Baguettes': {'venues': [{'id': '581fde7d8d169071e50aca7b',
#     'name': 'Baguettes Café',
#     'location': {'lat': 21.00121,
#      'lng': -89.694409,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.00121,
#        'lng': -89.694409}],
#      'distance': 2554,
#      'cc': 'MX',
#      'country': 'México',
#      'formattedAddress': ['México']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258905',
#     'hasPerk': False},
#    {'id': '58251dbf952467476eff33f2',
#     'name': 'Las BAGUETTES',
#     'location': {'lat': 20.992197,
#      'lng': -89.69239,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 20.992197,
#        'lng': -89.69239}],
#      'distance': 3149,
#      'postalCode': '97314',
#      'cc': 'MX',
#      'city': 'Caucel',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['97314 caucel, Yucatán', 'México']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258905',
#     'hasPerk': False}]},
#  'Desayunos': {'venues': []},
#  'Pollo': {'venues': [{'id': '4db88c9f0cb6ddfae4232cfc',
#     'name': 'Papa Pollo',
#     'location': {'address': 'Calle 59',
#      'crossStreet': 'Ciudad Caucel',
#      'lat': 20.99651,
#      'lng': -89.703163,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 20.99651,
#        'lng': -89.703163}],
#      'distance': 1952,
#      'postalCode': '97314',
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Calle 59 (Ciudad Caucel)',
#       '97314 Mérida, Yucatán',
#       'México']},
#     'categories': [],
#     'referralId': 'v-1583258905',
#     'hasPerk': False},
#    {'id': '4dc6f0bd2271f27051525832',
#     'name': 'Pollo Loco',
#     'location': {'crossStreet': 'Ciudad Caucel',
#      'lat': 21.00235226827982,
#      'lng': -89.70978865839686,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.00235226827982,
#        'lng': -89.70978865839686}],
#      'distance': 1016,
#      'postalCode': '97314',
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Ciudad Caucel', '97314 Mérida, Yucatán', 'México']},
#     'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#       'name': 'Fried Chicken Joint',
#       'pluralName': 'Fried Chicken Joints',
#       'shortName': 'Fried Chicken',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258905',
#     'hasPerk': False},
#    {'id': '537a7341498e6e09315f8dd6',
#     'name': 'Pollo Dorado',
#     'location': {'lat': 20.997283,
#      'lng': -89.703535,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 20.997283,
#        'lng': -89.703535}],
#      'distance': 1870,
#      'cc': 'MX',
#      'country': 'México',
#      'formattedAddress': ['México']},
#     'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#       'name': 'Fried Chicken Joint',
#       'pluralName': 'Fried Chicken Joints',
#       'shortName': 'Fried Chicken',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258905',
#     'hasPerk': False},
#    {'id': '55fe21bd498e557258ad6ad4',
#     'name': 'Pollo y Jalapeño',
#     'location': {'address': 'CALLE 61 NO 696',
#      'crossStreet': 'X 88 Y 88a',
#      'lat': 20.99217418386587,
#      'lng': -89.70519304275513,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 20.99217418386587,
#        'lng': -89.70519304275513}],
#      'distance': 2135,
#      'postalCode': '97314',
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['CALLE 61 NO 696 (X 88 Y 88a)',
#       '97314 Mérida, Yucatán',
#       'México']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258905',
#     'hasPerk': False},
#    {'id': '5490af3a498ef2141e76ce12',
#     'name': 'Pollo Feliz',
#     'location': {'address': 'Avenida 59A',
#      'lat': 21.004384025634604,
#      'lng': -89.6884713663688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.004384025634604,
#        'lng': -89.6884713663688}],
#      'distance': 3102,
#      'cc': 'MX',
#      'neighborhood': 'Caucel',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Avenida 59A', 'Mérida, Yucatán', 'México']},
#     'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#       'name': 'Fried Chicken Joint',
#       'pluralName': 'Fried Chicken Joints',
#       'shortName': 'Fried Chicken',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258905',
#     'hasPerk': False},
#    {'id': '5ca8f08fa4b51b003979e1a8',
#     'name': 'Pollo Brujo Caucel',
#     'location': {'address': 'calle 68',
#      'crossStreet': 'calle 37',
#      'lat': 21.00068,
#      'lng': -89.688644,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.00068,
#        'lng': -89.688644}],
#      'distance': 3150,
#      'postalCode': '97314',
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['calle 68 (calle 37)',
#       '97314 Mérida, Yucatán',
#       'México']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258905',
#     'hasPerk': False},
#    {'id': '56392469cd104946e833af7b',
#     'name': 'Pollos a la Leña "El Paisano"',
#     'location': {'address': 'Calle 31',
#      'crossStreet': 'x 78 y 80',
#      'lat': 21.004556,
#      'lng': -89.698845,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.004556,
#        'lng': -89.698845}],
#      'distance': 2028,
#      'postalCode': '97300',
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Calle 31 (x 78 y 80)',
#       '97300 Mérida, Yucatán',
#       'México']},
#     'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#       'name': 'Fried Chicken Joint',
#       'pluralName': 'Fried Chicken Joints',
#       'shortName': 'Fried Chicken',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258905',
#     'hasPerk': False},
#    {'id': '51bcbe7c498ed2fddde27bff',
#     'name': 'Costilitas  Asadas  Y Pollos A La Mostaza!',
#     'location': {'lat': 21.00297,
#      'lng': -89.70026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.00297,
#        'lng': -89.70026}],
#      'distance': 1917,
#      'cc': 'MX',
#      'country': 'México',
#      'formattedAddress': ['México']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258905',
#     'hasPerk': False},
#    {'id': '577ebbb1498e425c07f8da25',
#     'name': 'Venta de Pollos Asados',
#     'location': {'address': 'Los Almendros',
#      'lat': 20.996533,
#      'lng': -89.698562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 20.996533,
#        'lng': -89.698562}],
#      'distance': 2350,
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Los Almendros', 'Mérida, Yucatán', 'México']},
#     'categories': [{'id': '4bf58dd8d48988d14c941735',
#       'name': 'Wings Joint',
#       'pluralName': 'Wings Joints',
#       'shortName': 'Wings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258905',
#     'hasPerk': False}]},
#  'Pastor': {'venues': []},
#  'Pizza': {'venues': [{'id': '4f3b13b2e4b08082add2c0e1',
#     'name': "Domino's Pizza",
#     'location': {'lat': 21.003194056368685,
#      'lng': -89.71887604718012,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.003194056368685,
#        'lng': -89.71887604718012}],
#      'distance': 433,
#      'cc': 'MX',
#      'country': 'México',
#      'formattedAddress': ['México']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258906',
#     'hasPerk': False},
#    {'id': '517ddd7ce4b0ea626e496e4e',
#     'name': 'Pizza & Grill Luca',
#     'location': {'lat': 21.003299210846,
#      'lng': -89.70945834753827,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.003299210846,
#        'lng': -89.70945834753827}],
#      'distance': 997,
#      'cc': 'MX',
#      'country': 'México',
#      'formattedAddress': ['México']},
#     'categories': [{'id': '4bf58dd8d48988d117941735',
#       'name': 'Beer Garden',
#       'pluralName': 'Beer Gardens',
#       'shortName': 'Beer Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258906',
#     'hasPerk': False},
#    {'id': '574a4e60498ee45006fd8545',
#     'name': "Pizza Dominic's",
#     'location': {'address': 'Calle 39-A número 669 x 92 y 94',
#      'lat': 21.002998,
#      'lng': -89.706535,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.002998,
#        'lng': -89.706535}],
#      'distance': 1291,
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Calle 39-A número 669 x 92 y 94',
#       'Mérida, Yucatán',
#       'México']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258906',
#     'hasPerk': False},
#    {'id': '4f3f0cb4e4b0c47356acbdf5',
#     'name': "Pizza Pichu's",
#     'location': {'address': 'Calle 93',
#      'crossStreet': 'Ciudad Caucel',
#      'lat': 21.003125,
#      'lng': -89.705976,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.003125,
#        'lng': -89.705976}],
#      'distance': 1341,
#      'postalCode': '97314',
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Calle 93 (Ciudad Caucel)',
#       '97314 Mérida, Yucatán',
#       'México']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258906',
#     'hasPerk': False},
#    {'id': '509ab1ebf31c4be74baaf12c',
#     'name': 'Luigis Pizza & Sushito-Go',
#     'location': {'address': 'Av. 59 x 88',
#      'crossStreet': 'Ciudad Caucel',
#      'lat': 20.999065553230167,
#      'lng': -89.7103214263916,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 20.999065553230167,
#        'lng': -89.7103214263916}],
#      'distance': 1206,
#      'postalCode': '97314',
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Av. 59 x 88 (Ciudad Caucel)',
#       '97314 Mérida, Yucatán',
#       'México']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258906',
#     'hasPerk': False},
#    {'id': '5a52d87c065ef5736282d846',
#     'name': 'Little Caesars Pizza',
#     'location': {'lat': 20.997309,
#      'lng': -89.702518,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 20.997309,
#        'lng': -89.702518}],
#      'distance': 1955,
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Mérida, Yucatán', 'México']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258906',
#     'hasPerk': False},
#    {'id': '589bd4a551d19e5ec06f6c9e',
#     'name': 'Fratelli Pizza',
#     'location': {'address': 'Av. 70 entre',
#      'crossStreet': '37 y 39-A',
#      'lat': 21.002115,
#      'lng': -89.693886,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.002115,
#        'lng': -89.693886}],
#      'distance': 2584,
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Av. 70 entre (37 y 39-A)',
#       'Mérida, Yucatán',
#       'México']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258906',
#     'hasPerk': False},
#    {'id': '5840a468f68d8d55704f002d',
#     'name': 'Pizza Hut',
#     'location': {'lat': 21.004553025146507,
#      'lng': -89.68683017147545,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.004553025146507,
#        'lng': -89.68683017147545}],
#      'distance': 3270,
#      'cc': 'MX',
#      'country': 'México',
#      'formattedAddress': ['México']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258906',
#     'hasPerk': False},
#    {'id': '4eadf49ff5b936710bb5aee7',
#     'name': "Pizza Messina's",
#     'location': {'address': 'Calle 70',
#      'crossStreet': 'Ciudad Caucel',
#      'lat': 21.001706903832993,
#      'lng': -89.69417050951748,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 21.001706903832993,
#        'lng': -89.69417050951748}],
#      'distance': 2565,
#      'postalCode': '97314',
#      'cc': 'MX',
#      'city': 'Mérida',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['Calle 70 (Ciudad Caucel)',
#       '97314 Mérida, Yucatán',
#       'México']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258906',
#     'hasPerk': False},
#    {'id': '5c2d8164d90516002516957b',
#     'name': 'Pizza Secreta',
#     'location': {'address': 'calle 77 número 652c',
#      'crossStreet': '64a y 66',
#      'lat': 20.990513,
#      'lng': -89.696144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 20.990513,
#        'lng': -89.696144}],
#      'distance': 2938,
#      'postalCode': '97314',
#      'cc': 'MX',
#      'city': 'Caucel',
#      'state': 'Yucatán',
#      'country': 'México',
#      'formattedAddress': ['calle 77 número 652c (64a y 66)',
#       '97314 Caucel, Yucatán',
#       'México']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1583258906',
#     'hasPerk': False}]}}

# %%
fs_locs = {}
for result in fs_results:
    result_locs = []
    for i in range(len(fs_results[result]['venues'])):
        loc = []
        loc.append(fs_results[result]['venues'][i]['location']['lat'])
        loc.append(fs_results[result]['venues'][i]['location']['lng'])
        result_locs.append(loc)
    fs_locs[result] = result_locs
    
fs_locs
# Out:
# {'Baguettes': [[21.00121, -89.694409], [20.992197, -89.69239]],
#  'Desayunos': [],
#  'Pollo': [[20.99651, -89.703163],
#   [21.00235226827982, -89.70978865839686],
#   [20.997283, -89.703535],
#   [20.99217418386587, -89.70519304275513],
#   [21.004384025634604, -89.6884713663688],
#   [21.00068, -89.688644],
#   [21.004556, -89.698845],
#   [21.00297, -89.70026],
#   [20.996533, -89.698562]],
#  'Pastor': [],
#  'Pizza': [[21.003194056368685, -89.71887604718012],
#   [21.003299210846, -89.70945834753827],
#   [21.002998, -89.706535],
#   [21.003125, -89.705976],
#   [20.999065553230167, -89.7103214263916],
#   [20.997309, -89.702518],
#   [21.002115, -89.693886],
#   [21.004553025146507, -89.68683017147545],
#   [21.001706903832993, -89.69417050951748],
#   [20.990513, -89.696144]]}

# %%
fs_locs = {}
for result in fs_results:
    result_locs = []
    for i in range(len(fs_results[result]['venues'])):
        loc = {}
        loc[fs_results[result]['venues'][i]['name']] = []
        loc[fs_results[result]['venues'][i]['name']].append(fs_results[result]['venues'][i]['location']['lat'])
        loc[fs_results[result]['venues'][i]['name']].append(fs_results[result]['venues'][i]['location']['lng'])
        result_locs.append(loc)
    fs_locs[result] = result_locs
    
fs_locs
# Out:
# {'Baguettes': [{'Baguettes Café': [21.00121, -89.694409]},
#   {'Las BAGUETTES': [20.992197, -89.69239]}],
#  'Desayunos': [],
#  'Pollo': [{'Papa Pollo': [20.99651, -89.703163]},
#   {'Pollo Loco': [21.00235226827982, -89.70978865839686]},
#   {'Pollo Dorado': [20.997283, -89.703535]},
#   {'Pollo y Jalapeño': [20.99217418386587, -89.70519304275513]},
#   {'Pollo Feliz': [21.004384025634604, -89.6884713663688]},
#   {'Pollo Brujo Caucel': [21.00068, -89.688644]},
#   {'Pollos a la Leña "El Paisano"': [21.004556, -89.698845]},
#   {'Costilitas  Asadas  Y Pollos A La Mostaza!': [21.00297, -89.70026]},
#   {'Venta de Pollos Asados': [20.996533, -89.698562]}],
#  'Pastor': [],
#  'Pizza': [{"Domino's Pizza": [21.003194056368685, -89.71887604718012]},
#   {'Pizza & Grill Luca': [21.003299210846, -89.70945834753827]},
#   {"Pizza Dominic's": [21.002998, -89.706535]},
#   {"Pizza Pichu's": [21.003125, -89.705976]},
#   {'Luigis Pizza & Sushito-Go': [20.999065553230167, -89.7103214263916]},
#   {'Little Caesars Pizza': [20.997309, -89.702518]},
#   {'Fratelli Pizza': [21.002115, -89.693886]},
#   {'Pizza Hut': [21.004553025146507, -89.68683017147545]},
#   {"Pizza Messina's": [21.001706903832993, -89.69417050951748]},
#   {'Pizza Secreta': [20.990513, -89.696144]}]}

# %% [markdown]
# # User Location - GeoPy API

# %%
user_input = input('introduce lugar')
print(user_input)
# Out:
# introduce lugarokm
# okm

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="food-business-recommender")
location = geolocator.geocode("ciudad caucel merida yucatan")
#print(location.address)
print((location.latitude, location.longitude))
#print(location.raw)

# %% [markdown]
# ## Folium map

# %%
import folium

# %%
mapa=folium.Map(location=[21.007038700000003, -89.71818643311036], tiles='openstreetmap',zoom_start=12)

five_colors = ['red', 'orange', 'lightgreen', 'green', 'blue']
colors = dict(zip(fs_locs.keys(),five_colors))

folium.Circle([21.007038700000003, -89.71818643311036], radius=3000, icon=folium.Icon()).add_to(mapa)

for i in top_yf.index:
    folium.Marker(list(top_yf.loc[i][['latitude', 'longitude']]), popup='<b>'+top_yf.loc[i]['name']+'</b>', tooltip=top_yf.loc[i]['tipo'], icon=folium.Icon(color=colors[top_yf.loc[i]['tipo']], icon='info-sign')).add_to(mapa)

for key in top_types:
    for loc in fs_locs[key]:
        name = list(loc.keys())[0]
        folium.Marker(list(loc[name]), popup='<b>'+ name +'</b>', tooltip=key, icon=folium.Icon(color=colors[key], icon='info-sign')).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
