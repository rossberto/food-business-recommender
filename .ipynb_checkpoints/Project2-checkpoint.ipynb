# %% [markdown]
# # Main objective
# To recommend a food business restaurant by location and to show where the main competitors are.
#
# ## How it works
# This recommender uses offer, demand, satisfaction and trends to calculate a score.
#
# * Offer <-- Inegi
# * Demand <-- Google Trends
# * Satisfaction <-- Yelp
# * Trends <-- Google Trends Interest Over Time
#
# #### Score = Demand + Trends - Offer - Satisfaction
# Biggest score is the recommendation.

# %% [markdown]
# # Main libraries

# %%
from dotenv import load_dotenv
load_dotenv()

import os
import pandas as pd

# %% [markdown]
# # Inegi
# In this section we are getting the offer.
#
# We are using an Inegi database from https://inegi.org.mx/app/descarga/default.html
#
# Currently, we are using a preprocessed database from an attached notebook.

# %%
def prepareInegi():
    inegi = pd.read_csv('inegi.csv')
    inegi.drop(columns=['nom_estab', 'per_ocu', 'fecha_alta', 'nom_processed', 'tipoUniEco', 'localidad'], inplace=True)
    return inegi

# %%
inegi = prepareInegi()
inegi.entidad.value_counts()
# Out:
# VERACRUZ DE IGNACIO DE LA LLAVE             48459
# YUCATAN                                     17180
# SAN LUIS POTOSÍ                             15655
# TAMAULIPAS                                  15576
# SINALOA                                     15321
# SONORA                                      13198
# QUERÉTARO                                   12448
# TABASCO                                     11959
# QUINTANA ROO                                11275
# ZACATECAS                                    8474
# TLAXCALA                                     8267
# Name: entidad, dtype: int64

# %% [markdown]
# ## Filtering by state and city

# %%
def getInegiByState(state):
    return inegi[inegi['entidad']==state]

# %% [markdown]
# ### As use case for the demonstration we are selecting TAMAULIPAS

# %%
sinegi = getInegiByState('TAMAULIPAS')
sinegi.head()
# Out:
#           entidad      municipio    latitud   longitud  \
# 79856  TAMAULIPAS      Matamoros  25.869956 -97.514709
# 79857  TAMAULIPAS       Altamira  22.391528 -97.930704
# 79858  TAMAULIPAS  Valle Hermoso  25.670395 -97.815718
# 79859  TAMAULIPAS       Victoria  23.729669 -99.152546
# 79860  TAMAULIPAS       Altamira  22.334950 -97.865727
#
#                                   tipo  Cocina Económica  Antojitos  Pizza  \
# 79856  ['burg', 'burgu', 'hamburgues']                 0          0      0
# 79857                               []                 0          0      0
# 79858                               []                 0          0      0
# 79859                               []                 0          0      0
# 79860                      ['restaur']                 0          0      0
#
#        Hamburguesas  Hot Dogs  ...  Yucateca  Tabasqueña  Arrachera  Pastor  \
# 79856             1         0  ...         0           0          0       0
# 79857             0         0  ...         0           0          0       0
# 79858             0         0  ...         0           0          0       0
# 79859             0         0  ...         0           0          0       0
# 79860             0         0  ...         0           0          0       0
#
#        Birria  Barbacoa  Carnero  Pozole  Enchiladas  Chilaquiles
# 79856       0         0        0       0           0            0
# 79857       0         0        0       0           0            0
# 79858       0         0        0       0           0            0
# 79859       0         0        0       0           0            0
# 79860       0         0        0       0           0            0
#
# [5 rows x 46 columns]

# %%
sinegi['municipio'].value_counts()
# Out:
# Matamoros             2384
# Tampico               2161
# Reynosa               1972
# Nuevo Laredo          1757
# Victoria              1550
# Ciudad Madero         1156
# Altamira              1053
# El Mante               667
# Río Bravo              542
# Valle Hermoso          380
# Miguel Alemán          222
# González               211
# San Fernando           171
# Tula                   154
# Aldama                 134
# Camargo                109
# Gustavo Díaz Ordaz     108
# Xicoténcatl            104
# Soto la Marina          95
# Jaumave                 87
# Padilla                 85
# Ocampo                  74
# Hidalgo                 61
# Mier                    48
# Antiguo Morelos         37
# Abasolo                 36
# Llera                   36
# Jiménez                 30
# Nuevo Morelos           29
# Gómez Farías            27
# Guerrero                27
# Villagrán               11
# Güémez                  11
# San Carlos              10
# Burgos                   9
# Miquihuana               7
# Bustamante               5
# Palmillas                5
# Mainero                  5
# Cruillas                 3
# Méndez                   2
# Casas                    1
# Name: municipio, dtype: int64

# %%
def inegiFilterByMunicipio(municipio, df):
    return df.drop(df[df['municipio']!=municipio].index)

# %% [markdown]
# ### As use case we are selecting Tampico as the city

# %%
sinegi = inegiFilterByMunicipio('Tampico', sinegi)
sinegi.head()
# Out:
#           entidad municipio    latitud   longitud     tipo  Cocina Económica  \
# 79866  TAMAULIPAS   Tampico  22.273236 -97.874833       []                 0
# 79867  TAMAULIPAS   Tampico  22.255264 -97.861039  ['com']                 1
# 79868  TAMAULIPAS   Tampico  22.262607 -97.859094  ['com']                 1
# 79874  TAMAULIPAS   Tampico  22.213607 -97.849838       []                 0
# 79885  TAMAULIPAS   Tampico  22.302357 -97.860012       []                 0
#
#        Antojitos  Pizza  Hamburguesas  Hot Dogs  ...  Yucateca  Tabasqueña  \
# 79866          0      0             0         0  ...         0           0
# 79867          0      0             0         0  ...         0           0
# 79868          0      0             0         0  ...         0           0
# 79874          0      0             0         0  ...         0           0
# 79885          0      0             0         0  ...         0           0
#
#        Arrachera  Pastor  Birria  Barbacoa  Carnero  Pozole  Enchiladas  \
# 79866          0       0       0         0        0       0           0
# 79867          0       0       0         0        0       0           0
# 79868          0       0       0         0        0       0           0
# 79874          0       0       0         0        0       0           0
# 79885          0       0       0         0        0       0           0
#
#        Chilaquiles
# 79866            0
# 79867            0
# 79868            0
# 79874            0
# 79885            0
#
# [5 rows x 46 columns]

# %% [markdown]
# ## Obtaining offer by food type

# %%
foods = ['Cocina Económica', 'Antojitos', 'Pizza', 'Hamburguesas', 'Hot Dogs', 'Sushi', 'Tamales', 'Mariscos', 
         'Pescado', 'Tacos', 'Carne', 'Asada', 'Panuchos', 'Cochinita', 'Pollo', 'Desayunos', 'Tortas', 'Mondongo', 
         'Menudo', 'Memelas', 'Empanadas', 'Chicharrón', 'Gorditas', 'Costillas', 'Carnitas', 'Doraditas', 
         'Baguettes', 'Parrilla', 'Huaraches', 'Rosticería', 'China', 'Yucateca', 'Tabasqueña', 'Arrachera', 
         'Pastor', 'Birria', 'Barbacoa', 'Carnero', 'Pozole', 'Enchiladas', 'Chilaquiles']

# %%
def getInegiResults(df):
    results = {}

    for food in foods:
        results[food] = df[food].sum()

    return results

# %%
inegi_results = getInegiResults(sinegi)
inegi_results
# Out:
# {'Cocina Económica': 185,
#  'Antojitos': 156,
#  'Pizza': 31,
#  'Hamburguesas': 31,
#  'Hot Dogs': 23,
#  'Sushi': 2,
#  'Tamales': 39,
#  'Mariscos': 45,
#  'Pescado': 11,
#  'Tacos': 344,
#  'Carne': 0,
#  'Asada': 69,
#  'Panuchos': 0,
#  'Cochinita': 9,
#  'Pollo': 113,
#  'Desayunos': 2,
#  'Tortas': 252,
#  'Mondongo': 1,
#  'Menudo': 0,
#  'Memelas': 0,
#  'Empanadas': 9,
#  'Chicharrón': 1,
#  'Gorditas': 111,
#  'Costillas': 1,
#  'Carnitas': 38,
#  'Doraditas': 0,
#  'Baguettes': 5,
#  'Parrilla': 11,
#  'Huaraches': 1,
#  'Rosticería': 5,
#  'China': 0,
#  'Yucateca': 3,
#  'Tabasqueña': 0,
#  'Arrachera': 2,
#  'Pastor': 10,
#  'Birria': 0,
#  'Barbacoa': 26,
#  'Carnero': 0,
#  'Pozole': 0,
#  'Enchiladas': 1,
#  'Chilaquiles': 1}

# %% [markdown]
# ## Adding offer to the main dataframe df

# %%
def getInegiDfResult(inegi_results):
    return pd.DataFrame(inegi_results.items(), columns = ['Index', 'InegiCount']).set_index('Index')

# %%
df = getInegiDfResult(inegi_results)
df.head()
# Out:
#                   InegiCount
# Index
# Cocina Económica         185
# Antojitos                156
# Pizza                     31
# Hamburguesas              31
# Hot Dogs                  23

# %% [markdown]
# # Google Trends
# In this section we are getting the demand.
#
# We are using the Google Trends endpoint https://trends.google.com/trends by means of the Pytrends API https://pypi.org/project/pytrends/
#
#
# We check the trending of each food type in Mexico. Google trends gives information by state.

# %%
from pytrends.request import TrendReq

# %%
def getGoogleTrends(df):
    pytrends = TrendReq(hl='es-MX', tz=360)
    
    resultados = []
    for comida in foods:
        print(comida)
        pytrends.build_payload([comida], cat=71, geo='MX', gprop='')
        resultados.append(pytrends.interest_by_region(resolution='REGION', inc_low_vol=True, inc_geo_code=False))
    return resultados

# %%
google_trends = getGoogleTrends(sinegi)
google_trends
# Out:
# Cocina Económica
# Antojitos
# Pizza
# Hamburguesas
# Hot Dogs
# Sushi
# Tamales
# Mariscos
# Pescado
# Tacos
# Carne
# Asada
# Panuchos
# Cochinita
# Pollo
# Desayunos
# Tortas
# Mondongo
# Menudo
# Memelas
# Empanadas
# Chicharrón
# Gorditas
# Costillas
# Carnitas
# Doraditas
# Baguettes
# Parrilla
# Huaraches
# Rosticería
# China
# Yucateca
# Tabasqueña
# Arrachera
# Pastor
# Birria
# Barbacoa
# Carnero
# Pozole
# Enchiladas
# Chilaquiles
# [                      Cocina Económica
#  geoName
#  Aguascalientes                       0
#  Baja California                      0
#  Baja California Sur                  0
#  Campeche                             0
#  Chiapas                              0
#  Chihuahua                            0
#  Ciudad de México                    21
#  Coahuila de Zaragoza                 0
#  Colima                               0
#  Durango                              0
#  Estado de México                    29
#  Guanajuato                           0
#  Guerrero                             0
#  Hidalgo                              0
#  Jalisco                              0
#  Michoacán                            0
#  Morelos                              0
#  Nayarit                              0
#  Nuevo León                           0
#  Oaxaca                               0
#  Puebla                               0
#  Querétaro                            0
#  Quintana Roo                         0
#  San Luis Potosí                      0
#  Sinaloa                              0
#  Sonora                               0
#  Tabasco                              0
#  Tamaulipas                           0
#  Tlaxcala                             0
#  Veracruz                             0
#  Yucatán                            100
#  Zacatecas                            0,                       Antojitos
#  geoName
#  Aguascalientes               12
#  Baja California              24
#  Baja California Sur          20
#  Campeche                    100
#  Chiapas                      37
#  Chihuahua                    34
#  Ciudad de México             20
#  Coahuila de Zaragoza         15
#  Colima                       29
#  Durango                      26
#  Estado de México             17
#  Guanajuato                   13
#  Guerrero                     21
#  Hidalgo                      32
#  Jalisco                      18
#  Michoacán                    18
#  Morelos                      14
#  Nayarit                      35
#  Nuevo León                   68
#  Oaxaca                       32
#  Puebla                       35
#  Querétaro                    21
#  Quintana Roo                 57
#  San Luis Potosí              39
#  Sinaloa                      24
#  Sonora                       23
#  Tabasco                      48
#  Tamaulipas                   29
#  Tlaxcala                     22
#  Veracruz                     64
#  Yucatán                      39
#  Zacatecas                    42,                       Pizza
#  geoName
#  Aguascalientes           70
#  Baja California          82
#  Baja California Sur      72
#  Campeche                 80
#  Chiapas                  79
#  Chihuahua                64
#  Ciudad de México         84
#  Coahuila de Zaragoza     70
#  Colima                   80
#  Durango                  64
#  Estado de México         62
#  Guanajuato               59
#  Guerrero                 54
#  Hidalgo                  43
#  Jalisco                  76
#  Michoacán                57
#  Morelos                  66
#  Nayarit                  73
#  Nuevo León               92
#  Oaxaca                   58
#  Puebla                   64
#  Querétaro                80
#  Quintana Roo             97
#  San Luis Potosí          80
#  Sinaloa                  72
#  Sonora                   73
#  Tabasco                  75
#  Tamaulipas               62
#  Tlaxcala                 38
#  Veracruz                 62
#  Yucatán                 100
#  Zacatecas                45,                       Hamburguesas
#  geoName
#  Aguascalientes                  63
#  Baja California                 70
#  Baja California Sur             42
#  Campeche                        49
#  Chiapas                         42
#  Chihuahua                       77
#  Ciudad de México                69
#  Coahuila de Zaragoza            71
#  Colima                         100
#  Durango                         54
#  Estado de México                50
#  Guanajuato                      53
#  Guerrero                        34
#  Hidalgo                         48
#  Jalisco                         84
#  Michoacán                       61
#  Morelos                         51
#  Nayarit                         58
#  Nuevo León                      91
#  Oaxaca                          41
#  Puebla                          55
#  Querétaro                       66
#  Quintana Roo                    48
#  San Luis Potosí                 56
#  Sinaloa                         86
#  Sonora                          77
#  Tabasco                         52
#  Tamaulipas                      59
#  Tlaxcala                        39
#  Veracruz                        60
#  Yucatán                         51
#  Zacatecas                       71,                       Hot Dogs
#  geoName
#  Aguascalientes              33
#  Baja California             99
#  Baja California Sur         78
#  Campeche                     0
#  Chiapas                     22
#  Chihuahua                   48
#  Ciudad de México            50
#  Coahuila de Zaragoza        37
#  Colima                      52
#  Durango                     42
#  Estado de México            30
#  Guanajuato                  29
#  Guerrero                     0
#  Hidalgo                     22
#  Jalisco                     51
#  Michoacán                   19
#  Morelos                     25
#  Nayarit                     47
#  Nuevo León                  49
#  Oaxaca                       0
#  Puebla                      30
#  Querétaro                   38
#  Quintana Roo                40
#  San Luis Potosí             30
#  Sinaloa                     95
#  Sonora                     100
#  Tabasco                     30
#  Tamaulipas                  45
#  Tlaxcala                     0
#  Veracruz                    35
#  Yucatán                     31
#  Zacatecas                    0,                       Sushi
#  geoName
#  Aguascalientes           41
#  Baja California          46
#  Baja California Sur      52
#  Campeche                 10
#  Chiapas                   8
#  Chihuahua                17
#  Ciudad de México         41
#  Coahuila de Zaragoza     15
#  Colima                   27
#  Durango                  15
#  Estado de México         17
#  Guanajuato               20
#  Guerrero                  9
#  Hidalgo                  10
#  Jalisco                  32
#  Michoacán                 6
#  Morelos                  19
#  Nayarit                  32
#  Nuevo León               25
#  Oaxaca                    7
#  Puebla                   13
#  Querétaro                28
#  Quintana Roo             39
#  San Luis Potosí          15
#  Sinaloa                 100
#  Sonora                   83
#  Tabasco                   7
#  Tamaulipas                8
#  Tlaxcala                  6
#  Veracruz                  8
#  Yucatán                  30
#  Zacatecas                12,                       Tamales
#  geoName
#  Aguascalientes             70
#  Baja California            81
#  Baja California Sur        78
#  Campeche                   65
#  Chiapas                    40
#  Chihuahua                  82
#  Ciudad de México           65
#  Coahuila de Zaragoza       77
#  Colima                     58
#  Durango                    79
#  Estado de México           67
#  Guanajuato                 58
#  Guerrero                   55
#  Hidalgo                    69
#  Jalisco                    75
#  Michoacán                  63
#  Morelos                    72
#  Nayarit                    76
#  Nuevo León                 99
#  Oaxaca                     57
#  Puebla                     60
#  Querétaro                  68
#  Quintana Roo               61
#  San Luis Potosí            71
#  Sinaloa                    65
#  Sonora                     86
#  Tabasco                    44
#  Tamaulipas                100
#  Tlaxcala                   57
#  Veracruz                   83
#  Yucatán                    52
#  Zacatecas                  62,                       Mariscos
#  geoName
#  Aguascalientes              36
#  Baja California             45
#  Baja California Sur         45
#  Campeche                    23
#  Chiapas                     20
#  Chihuahua                   36
#  Ciudad de México            34
#  Coahuila de Zaragoza        24
#  Colima                     100
#  Durango                     30
#  Estado de México            20
#  Guanajuato                  36
#  Guerrero                    26
#  Hidalgo                     22
#  Jalisco                     79
#  Michoacán                   32
#  Morelos                     22
#  Nayarit                     89
#  Nuevo León                  50
#  Oaxaca                      21
#  Puebla                      29
#  Querétaro                   38
#  Quintana Roo                35
#  San Luis Potosí             38
#  Sinaloa                     81
#  Sonora                      62
#  Tabasco                     27
#  Tamaulipas                  44
#  Tlaxcala                    19
#  Veracruz                    26
#  Yucatán                     31
#  Zacatecas                   29,                       Pescado
#  geoName
#  Aguascalientes             61
#  Baja California            74
#  Baja California Sur       100
#  Campeche                   61
#  Chiapas                    47
#  Chihuahua                  65
#  Ciudad de México           49
#  Coahuila de Zaragoza       57
#  Colima                     76
#  Durango                    66
#  Estado de México           45
#  Guanajuato                 45
#  Guerrero                   61
#  Hidalgo                    46
#  Jalisco                    65
#  Michoacán                  58
#  Morelos                    46
#  Nayarit                    93
#  Nuevo León                 59
#  Oaxaca                     50
#  Puebla                     45
#  Querétaro                  54
#  Quintana Roo               70
#  San Luis Potosí            52
#  Sinaloa                    64
#  Sonora                     65
#  Tabasco                    53
#  Tamaulipas                 56
#  Tlaxcala                   42
#  Veracruz                   51
#  Yucatán                    54
#  Zacatecas                  57,                       Tacos
#  geoName
#  Aguascalientes           32
#  Baja California          36
#  Baja California Sur      31
#  Campeche                 20
#  Chiapas                  24
#  Chihuahua                37
#  Ciudad de México         32
#  Coahuila de Zaragoza     32
#  Colima                  100
#  Durango                  32
#  Estado de México         22
#  Guanajuato               26
#  Guerrero                 26
#  Hidalgo                  20
#  Jalisco                  54
#  Michoacán                28
#  Morelos                  25
#  Nayarit                  43
#  Nuevo León               78
#  Oaxaca                   24
#  Puebla                   29
#  Querétaro                35
#  Quintana Roo             34
#  San Luis Potosí          28
#  Sinaloa                  59
#  Sonora                   31
#  Tabasco                  26
#  Tamaulipas               28
#  Tlaxcala                 20
#  Veracruz                 27
#  Yucatán                  21
#  Zacatecas                26,                       Carne
#  geoName
#  Aguascalientes           70
#  Baja California          74
#  Baja California Sur      88
#  Campeche                 75
#  Chiapas                  64
#  Chihuahua                85
#  Ciudad de México         62
#  Coahuila de Zaragoza     84
#  Colima                  100
#  Durango                  83
#  Estado de México         60
#  Guanajuato               64
#  Guerrero                 48
#  Hidalgo                  62
#  Jalisco                  82
#  Michoacán                70
#  Morelos                  61
#  Nayarit                  88
#  Nuevo León               78
#  Oaxaca                   49
#  Puebla                   63
#  Querétaro                74
#  Quintana Roo             65
#  San Luis Potosí          67
#  Sinaloa                  84
#  Sonora                   94
#  Tabasco                  82
#  Tamaulipas               81
#  Tlaxcala                 58
#  Veracruz                 66
#  Yucatán                  68
#  Zacatecas                71,                       Asada
#  geoName
#  Aguascalientes           52
#  Baja California          66
#  Baja California Sur      71
#  Campeche                 35
#  Chiapas                  46
#  Chihuahua                55
#  Ciudad de México         29
#  Coahuila de Zaragoza     72
#  Colima                   92
#  Durango                  84
#  Estado de México         26
#  Guanajuato               44
#  Guerrero                 26
#  Hidalgo                  35
#  Jalisco                  53
#  Michoacán                46
#  Morelos                  29
#  Nayarit                  87
#  Nuevo León               92
#  Oaxaca                   24
#  Puebla                   44
#  Querétaro                48
#  Quintana Roo             38
#  San Luis Potosí          48
#  Sinaloa                 100
#  Sonora                   95
#  Tabasco                  44
#  Tamaulipas               66
#  Tlaxcala                 30
#  Veracruz                 33
#  Yucatán                  37
#  Zacatecas                44,                       Panuchos
#  geoName
#  Aguascalientes               0
#  Baja California              5
#  Baja California Sur          0
#  Campeche                    90
#  Chiapas                     14
#  Chihuahua                    4
#  Ciudad de México            15
#  Coahuila de Zaragoza         5
#  Colima                       0
#  Durango                      0
#  Estado de México            12
#  Guanajuato                   7
#  Guerrero                     0
#  Hidalgo                     10
#  Jalisco                      7
#  Michoacán                    5
#  Morelos                     13
#  Nayarit                      0
#  Nuevo León                   8
#  Oaxaca                       8
#  Puebla                      11
#  Querétaro                   12
#  Quintana Roo                56
#  San Luis Potosí              0
#  Sinaloa                      0
#  Sonora                       5
#  Tabasco                     48
#  Tamaulipas                  12
#  Tlaxcala                     0
#  Veracruz                    18
#  Yucatán                    100
#  Zacatecas                    0,                       Cochinita
#  geoName
#  Aguascalientes               41
#  Baja California              68
#  Baja California Sur          40
#  Campeche                     84
#  Chiapas                      43
#  Chihuahua                    26
#  Ciudad de México             63
#  Coahuila de Zaragoza         25
#  Colima                       33
#  Durango                      22
#  Estado de México             57
#  Guanajuato                   23
#  Guerrero                     33
#  Hidalgo                      40
#  Jalisco                      22
#  Michoacán                    20
#  Morelos                      42
#  Nayarit                      19
#  Nuevo León                   25
#  Oaxaca                       35
#  Puebla                       43
#  Querétaro                    40
#  Quintana Roo                 77
#  San Luis Potosí              31
#  Sinaloa                      50
#  Sonora                       47
#  Tabasco                     100
#  Tamaulipas                   41
#  Tlaxcala                     36
#  Veracruz                     71
#  Yucatán                      80
#  Zacatecas                    25,                       Pollo
#  geoName
#  Aguascalientes           54
#  Baja California          74
#  Baja California Sur      75
#  Campeche                 88
#  Chiapas                  87
#  Chihuahua                63
#  Ciudad de México         48
#  Coahuila de Zaragoza     76
#  Colima                   77
#  Durango                  57
#  Estado de México         50
#  Guanajuato               49
#  Guerrero                 50
#  Hidalgo                  55
#  Jalisco                  75
#  Michoacán                56
#  Morelos                  55
#  Nayarit                  71
#  Nuevo León               83
#  Oaxaca                   60
#  Puebla                   53
#  Querétaro                53
#  Quintana Roo             73
#  San Luis Potosí          59
#  Sinaloa                  69
#  Sonora                   65
#  Tabasco                 100
#  Tamaulipas               89
#  Tlaxcala                 51
#  Veracruz                 74
#  Yucatán                  81
#  Zacatecas                55,                       Desayunos
#  geoName
#  Aguascalientes               62
#  Baja California              78
#  Baja California Sur          85
#  Campeche                     88
#  Chiapas                      89
#  Chihuahua                    63
#  Ciudad de México             74
#  Coahuila de Zaragoza         56
#  Colima                       84
#  Durango                      61
#  Estado de México             64
#  Guanajuato                   53
#  Guerrero                     49
#  Hidalgo                      73
#  Jalisco                      85
#  Michoacán                    59
#  Morelos                      57
#  Nayarit                     100
#  Nuevo León                   57
#  Oaxaca                       72
#  Puebla                       70
#  Querétaro                    79
#  Quintana Roo                 77
#  San Luis Potosí              69
#  Sinaloa                      74
#  Sonora                       66
#  Tabasco                      68
#  Tamaulipas                   50
#  Tlaxcala                     59
#  Veracruz                     68
#  Yucatán                      75
#  Zacatecas                    57,                       Tortas
#  geoName
#  Aguascalientes            24
#  Baja California           19
#  Baja California Sur       19
#  Campeche                  28
#  Chiapas                   13
#  Chihuahua                 22
#  Ciudad de México          35
#  Coahuila de Zaragoza      14
#  Colima                    47
#  Durango                   16
#  Estado de México          24
#  Guanajuato                20
#  Guerrero                  12
#  Hidalgo                   20
#  Jalisco                  100
#  Michoacán                 26
#  Morelos                   25
#  Nayarit                   41
#  Nuevo León                39
#  Oaxaca                    14
#  Puebla                    16
#  Querétaro                 25
#  Quintana Roo              75
#  San Luis Potosí           39
#  Sinaloa                   38
#  Sonora                    17
#  Tabasco                   15
#  Tamaulipas                21
#  Tlaxcala                  14
#  Veracruz                  22
#  Yucatán                   22
#  Zacatecas                 18,                       Mondongo
#  geoName
#  Aguascalientes               7
#  Baja California              8
#  Baja California Sur         10
#  Campeche                   100
#  Chiapas                     38
#  Chihuahua                    4
#  Ciudad de México            10
#  Coahuila de Zaragoza         6
#  Colima                       0
#  Durango                      8
#  Estado de México             8
#  Guanajuato                   6
#  Guerrero                     5
#  Hidalgo                      9
#  Jalisco                      8
#  Michoacán                    6
#  Morelos                      7
#  Nayarit                     10
#  Nuevo León                   8
#  Oaxaca                      22
#  Puebla                      12
#  Querétaro                    9
#  Quintana Roo                53
#  San Luis Potosí              6
#  Sinaloa                      6
#  Sonora                      10
#  Tabasco                     94
#  Tamaulipas                  27
#  Tlaxcala                     0
#  Veracruz                    56
#  Yucatán                     77
#  Zacatecas                    0,                       Menudo
#  geoName
#  Aguascalientes            52
#  Baja California           89
#  Baja California Sur       63
#  Campeche                   7
#  Chiapas                   16
#  Chihuahua                100
#  Ciudad de México          17
#  Coahuila de Zaragoza      74
#  Colima                    42
#  Durango                   58
#  Estado de México          13
#  Guanajuato                43
#  Guerrero                  16
#  Hidalgo                   13
#  Jalisco                   60
#  Michoacán                 43
#  Morelos                   14
#  Nayarit                   48
#  Nuevo León                76
#  Oaxaca                    14
#  Puebla                    13
#  Querétaro                 45
#  Quintana Roo              16
#  San Luis Potosí           47
#  Sinaloa                   63
#  Sonora                    82
#  Tabasco                   15
#  Tamaulipas                70
#  Tlaxcala                   9
#  Veracruz                  14
#  Yucatán                   13
#  Zacatecas                 43,                       Memelas
#  geoName
#  Aguascalientes             20
#  Baja California            20
#  Baja California Sur         0
#  Campeche                    0
#  Chiapas                     0
#  Chihuahua                  18
#  Ciudad de México           27
#  Coahuila de Zaragoza       16
#  Colima                      0
#  Durango                     0
#  Estado de México           18
#  Guanajuato                 16
#  Guerrero                    0
#  Hidalgo                     0
#  Jalisco                    16
#  Michoacán                   8
#  Morelos                    10
#  Nayarit                     0
#  Nuevo León                 23
#  Oaxaca                    100
#  Puebla                     81
#  Querétaro                  25
#  Quintana Roo               49
#  San Luis Potosí            16
#  Sinaloa                    12
#  Sonora                     12
#  Tabasco                    42
#  Tamaulipas                 18
#  Tlaxcala                    0
#  Veracruz                   68
#  Yucatán                    36
#  Zacatecas                   0,                       Empanadas
#  geoName
#  Aguascalientes               27
#  Baja California              37
#  Baja California Sur          57
#  Campeche                     39
#  Chiapas                      37
#  Chihuahua                    60
#  Ciudad de México             25
#  Coahuila de Zaragoza         73
#  Colima                       44
#  Durango                      56
#  Estado de México             25
#  Guanajuato                   27
#  Guerrero                     28
#  Hidalgo                      21
#  Jalisco                      31
#  Michoacán                    25
#  Morelos                      24
#  Nayarit                      48
#  Nuevo León                  100
#  Oaxaca                       29
#  Puebla                       25
#  Querétaro                    30
#  Quintana Roo                 57
#  San Luis Potosí              30
#  Sinaloa                      37
#  Sonora                       47
#  Tabasco                      43
#  Tamaulipas                   59
#  Tlaxcala                     23
#  Veracruz                     40
#  Yucatán                      37
#  Zacatecas                    35,                       Chicharrón
#  geoName
#  Aguascalientes                85
#  Baja California               43
#  Baja California Sur            0
#  Campeche                       0
#  Chiapas                       63
#  Chihuahua                     67
#  Ciudad de México              79
#  Coahuila de Zaragoza          79
#  Colima                         0
#  Durango                       96
#  Estado de México              87
#  Guanajuato                    74
#  Guerrero                      66
#  Hidalgo                       74
#  Jalisco                       69
#  Michoacán                     54
#  Morelos                       49
#  Nayarit                      100
#  Nuevo León                    82
#  Oaxaca                        59
#  Puebla                        64
#  Querétaro                     75
#  Quintana Roo                  91
#  San Luis Potosí               53
#  Sinaloa                       46
#  Sonora                        36
#  Tabasco                       68
#  Tamaulipas                    75
#  Tlaxcala                       0
#  Veracruz                      70
#  Yucatán                       72
#  Zacatecas                      0,                       Gorditas
#  geoName
#  Aguascalientes              46
#  Baja California             33
#  Baja California Sur         40
#  Campeche                    22
#  Chiapas                     22
#  Chihuahua                   47
#  Ciudad de México            24
#  Coahuila de Zaragoza        83
#  Colima                      28
#  Durango                     98
#  Estado de México            24
#  Guanajuato                  37
#  Guerrero                    19
#  Hidalgo                     28
#  Jalisco                     33
#  Michoacán                   41
#  Morelos                     23
#  Nayarit                     44
#  Nuevo León                 100
#  Oaxaca                      12
#  Puebla                      19
#  Querétaro                   47
#  Quintana Roo                25
#  San Luis Potosí             43
#  Sinaloa                     45
#  Sonora                      35
#  Tabasco                     19
#  Tamaulipas                  82
#  Tlaxcala                    23
#  Veracruz                    23
#  Yucatán                     18
#  Zacatecas                   53,                       Costillas
#  geoName
#  Aguascalientes              100
#  Baja California              66
#  Baja California Sur          66
#  Campeche                     70
#  Chiapas                      52
#  Chihuahua                    82
#  Ciudad de México             67
#  Coahuila de Zaragoza         82
#  Colima                       72
#  Durango                      54
#  Estado de México             71
#  Guanajuato                   44
#  Guerrero                     57
#  Hidalgo                      55
#  Jalisco                      71
#  Michoacán                    51
#  Morelos                      74
#  Nayarit                      65
#  Nuevo León                   48
#  Oaxaca                       49
#  Puebla                       61
#  Querétaro                    63
#  Quintana Roo                 54
#  San Luis Potosí              50
#  Sinaloa                      54
#  Sonora                       50
#  Tabasco                      83
#  Tamaulipas                   50
#  Tlaxcala                     64
#  Veracruz                     61
#  Yucatán                      51
#  Zacatecas                    64,                       Carnitas
#  geoName
#  Aguascalientes              53
#  Baja California             51
#  Baja California Sur         45
#  Campeche                    52
#  Chiapas                     32
#  Chihuahua                   38
#  Ciudad de México            50
#  Coahuila de Zaragoza        45
#  Colima                     100
#  Durango                     45
#  Estado de México            45
#  Guanajuato                  48
#  Guerrero                    38
#  Hidalgo                     39
#  Jalisco                     54
#  Michoacán                   53
#  Morelos                     35
#  Nayarit                    100
#  Nuevo León                  28
#  Oaxaca                      37
#  Puebla                      50
#  Querétaro                   47
#  Quintana Roo                49
#  San Luis Potosí             43
#  Sinaloa                     61
#  Sonora                      62
#  Tabasco                     72
#  Tamaulipas                  44
#  Tlaxcala                    30
#  Veracruz                    37
#  Yucatán                     44
#  Zacatecas                   45,                       Doraditas
#  geoName
#  Aguascalientes                0
#  Baja California              13
#  Baja California Sur           0
#  Campeche                      0
#  Chiapas                       0
#  Chihuahua                     0
#  Ciudad de México              8
#  Coahuila de Zaragoza          0
#  Colima                        0
#  Durango                       0
#  Estado de México              7
#  Guanajuato                    0
#  Guerrero                      0
#  Hidalgo                       0
#  Jalisco                       7
#  Michoacán                     0
#  Morelos                       0
#  Nayarit                       0
#  Nuevo León                   12
#  Oaxaca                        0
#  Puebla                        7
#  Querétaro                     0
#  Quintana Roo                  0
#  San Luis Potosí               0
#  Sinaloa                       0
#  Sonora                        0
#  Tabasco                       0
#  Tamaulipas                    0
#  Tlaxcala                      0
#  Veracruz                      7
#  Yucatán                     100
#  Zacatecas                     0,                       Baguettes
#  geoName
#  Aguascalientes                0
#  Baja California               0
#  Baja California Sur           0
#  Campeche                      0
#  Chiapas                       0
#  Chihuahua                     0
#  Ciudad de México             29
#  Coahuila de Zaragoza          0
#  Colima                        0
#  Durango                       0
#  Estado de México             16
#  Guanajuato                   25
#  Guerrero                      0
#  Hidalgo                      47
#  Jalisco                      51
#  Michoacán                    36
#  Morelos                       0
#  Nayarit                       0
#  Nuevo León                    9
#  Oaxaca                        0
#  Puebla                       21
#  Querétaro                    56
#  Quintana Roo                 54
#  San Luis Potosí               0
#  Sinaloa                      21
#  Sonora                        0
#  Tabasco                       0
#  Tamaulipas                    0
#  Tlaxcala                      0
#  Veracruz                     25
#  Yucatán                     100
#  Zacatecas                     0,                       Parrilla
#  geoName
#  Aguascalientes              13
#  Baja California             12
#  Baja California Sur         18
#  Campeche                    27
#  Chiapas                     46
#  Chihuahua                   12
#  Ciudad de México            33
#  Coahuila de Zaragoza        17
#  Colima                      25
#  Durango                     15
#  Estado de México            19
#  Guanajuato                  21
#  Guerrero                    16
#  Hidalgo                     16
#  Jalisco                     22
#  Michoacán                   16
#  Morelos                     15
#  Nayarit                     15
#  Nuevo León                  27
#  Oaxaca                      14
#  Puebla                      15
#  Querétaro                   37
#  Quintana Roo                86
#  San Luis Potosí             17
#  Sinaloa                     13
#  Sonora                      12
#  Tabasco                     41
#  Tamaulipas                  18
#  Tlaxcala                    10
#  Veracruz                    19
#  Yucatán                    100
#  Zacatecas                   16,                       Huaraches
#  geoName
#  Aguascalientes               30
#  Baja California              27
#  Baja California Sur          52
#  Campeche                     33
#  Chiapas                      40
#  Chihuahua                    24
#  Ciudad de México             33
#  Coahuila de Zaragoza         24
#  Colima                       18
#  Durango                      23
#  Estado de México             30
#  Guanajuato                   67
#  Guerrero                     31
#  Hidalgo                      22
#  Jalisco                      33
#  Michoacán                    34
#  Morelos                      20
#  Nayarit                      38
#  Nuevo León                   18
#  Oaxaca                      100
#  Puebla                       18
#  Querétaro                    36
#  Quintana Roo                 30
#  San Luis Potosí              29
#  Sinaloa                      25
#  Sonora                       21
#  Tabasco                      26
#  Tamaulipas                   22
#  Tlaxcala                     26
#  Veracruz                     29
#  Yucatán                      34
#  Zacatecas                    28,                       Rosticería
#  geoName
#  Aguascalientes                 0
#  Baja California                0
#  Baja California Sur            0
#  Campeche                       0
#  Chiapas                        0
#  Chihuahua                      0
#  Ciudad de México              43
#  Coahuila de Zaragoza           0
#  Colima                         0
#  Durango                        0
#  Estado de México               0
#  Guanajuato                     0
#  Guerrero                       0
#  Hidalgo                        0
#  Jalisco                      100
#  Michoacán                      0
#  Morelos                        0
#  Nayarit                        0
#  Nuevo León                     0
#  Oaxaca                         0
#  Puebla                         0
#  Querétaro                      0
#  Quintana Roo                   0
#  San Luis Potosí                0
#  Sinaloa                        0
#  Sonora                         0
#  Tabasco                        0
#  Tamaulipas                     0
#  Tlaxcala                       0
#  Veracruz                       0
#  Yucatán                        0
#  Zacatecas                      0,                       China
#  geoName
#  Aguascalientes           29
#  Baja California         100
#  Baja California Sur      67
#  Campeche                 37
#  Chiapas                  46
#  Chihuahua                40
#  Ciudad de México         34
#  Coahuila de Zaragoza     27
#  Colima                   43
#  Durango                  30
#  Estado de México         27
#  Guanajuato               31
#  Guerrero                 32
#  Hidalgo                  28
#  Jalisco                  44
#  Michoacán                36
#  Morelos                  42
#  Nayarit                  55
#  Nuevo León               40
#  Oaxaca                   37
#  Puebla                   33
#  Querétaro                33
#  Quintana Roo             49
#  San Luis Potosí          31
#  Sinaloa                  89
#  Sonora                   74
#  Tabasco                  33
#  Tamaulipas               32
#  Tlaxcala                 23
#  Veracruz                 31
#  Yucatán                  52
#  Zacatecas                32,                       Yucateca
#  geoName
#  Aguascalientes               6
#  Baja California              2
#  Baja California Sur          0
#  Campeche                    24
#  Chiapas                      4
#  Chihuahua                    1
#  Ciudad de México            11
#  Coahuila de Zaragoza         2
#  Colima                       0
#  Durango                      2
#  Estado de México             5
#  Guanajuato                   3
#  Guerrero                     3
#  Hidalgo                      2
#  Jalisco                      3
#  Michoacán                    2
#  Morelos                      4
#  Nayarit                      0
#  Nuevo León                   2
#  Oaxaca                       3
#  Puebla                       4
#  Querétaro                    6
#  Quintana Roo                41
#  San Luis Potosí              3
#  Sinaloa                      1
#  Sonora                       2
#  Tabasco                     11
#  Tamaulipas                   2
#  Tlaxcala                     2
#  Veracruz                     5
#  Yucatán                    100
#  Zacatecas                    4,                       Tabasqueña
#  geoName
#  Aguascalientes                 0
#  Baja California                0
#  Baja California Sur            0
#  Campeche                      67
#  Chiapas                        4
#  Chihuahua                      0
#  Ciudad de México               1
#  Coahuila de Zaragoza           0
#  Colima                         0
#  Durango                        0
#  Estado de México               0
#  Guanajuato                     0
#  Guerrero                       0
#  Hidalgo                        0
#  Jalisco                        0
#  Michoacán                      0
#  Morelos                        0
#  Nayarit                        0
#  Nuevo León                     1
#  Oaxaca                         1
#  Puebla                         1
#  Querétaro                      0
#  Quintana Roo                   8
#  San Luis Potosí                0
#  Sinaloa                        0
#  Sonora                         0
#  Tabasco                      100
#  Tamaulipas                     0
#  Tlaxcala                       0
#  Veracruz                       3
#  Yucatán                       12
#  Zacatecas                      0,                       Arrachera
#  geoName
#  Aguascalientes               29
#  Baja California              18
#  Baja California Sur          42
#  Campeche                     33
#  Chiapas                      15
#  Chihuahua                    16
#  Ciudad de México             34
#  Coahuila de Zaragoza         31
#  Colima                       24
#  Durango                      22
#  Estado de México             26
#  Guanajuato                   38
#  Guerrero                     20
#  Hidalgo                      32
#  Jalisco                      31
#  Michoacán                    31
#  Morelos                      38
#  Nayarit                      25
#  Nuevo León                   39
#  Oaxaca                       21
#  Puebla                       24
#  Querétaro                    38
#  Quintana Roo                100
#  San Luis Potosí              69
#  Sinaloa                      12
#  Sonora                       13
#  Tabasco                      19
#  Tamaulipas                   36
#  Tlaxcala                     20
#  Veracruz                     24
#  Yucatán                      47
#  Zacatecas                    23,                       Pastor
#  geoName
#  Aguascalientes            52
#  Baja California           36
#  Baja California Sur       56
#  Campeche                 100
#  Chiapas                   52
#  Chihuahua                 61
#  Ciudad de México          82
#  Coahuila de Zaragoza      78
#  Colima                    61
#  Durango                   55
#  Estado de México          69
#  Guanajuato                57
#  Guerrero                  92
#  Hidalgo                   62
#  Jalisco                   59
#  Michoacán                 64
#  Morelos                   78
#  Nayarit                   55
#  Nuevo León                74
#  Oaxaca                    53
#  Puebla                    81
#  Querétaro                 63
#  Quintana Roo              85
#  San Luis Potosí           46
#  Sinaloa                   34
#  Sonora                    42
#  Tabasco                   82
#  Tamaulipas                44
#  Tlaxcala                  58
#  Veracruz                  82
#  Yucatán                   99
#  Zacatecas                 53,                       Birria
#  geoName
#  Aguascalientes            57
#  Baja California           78
#  Baja California Sur       59
#  Campeche                  15
#  Chiapas                   13
#  Chihuahua                 21
#  Ciudad de México          41
#  Coahuila de Zaragoza      17
#  Colima                    68
#  Durango                   31
#  Estado de México          33
#  Guanajuato                31
#  Guerrero                   9
#  Hidalgo                   21
#  Jalisco                   80
#  Michoacán                 46
#  Morelos                   19
#  Nayarit                   92
#  Nuevo León                13
#  Oaxaca                    15
#  Puebla                    28
#  Querétaro                 21
#  Quintana Roo              18
#  San Luis Potosí           13
#  Sinaloa                  100
#  Sonora                    45
#  Tabasco                   15
#  Tamaulipas                12
#  Tlaxcala                  16
#  Veracruz                  18
#  Yucatán                   14
#  Zacatecas                 73,                       Barbacoa
#  geoName
#  Aguascalientes              33
#  Baja California             37
#  Baja California Sur         34
#  Campeche                    47
#  Chiapas                     56
#  Chihuahua                   58
#  Ciudad de México            40
#  Coahuila de Zaragoza        35
#  Colima                     100
#  Durango                     37
#  Estado de México            34
#  Guanajuato                  23
#  Guerrero                    47
#  Hidalgo                     43
#  Jalisco                     90
#  Michoacán                   38
#  Morelos                     36
#  Nayarit                     21
#  Nuevo León                  44
#  Oaxaca                      37
#  Puebla                      34
#  Querétaro                   59
#  Quintana Roo                48
#  San Luis Potosí             40
#  Sinaloa                     48
#  Sonora                      58
#  Tabasco                     94
#  Tamaulipas                  35
#  Tlaxcala                    34
#  Veracruz                    61
#  Yucatán                     32
#  Zacatecas                   26,                       Carnero
#  geoName
#  Aguascalientes             27
#  Baja California            11
#  Baja California Sur         0
#  Campeche                   11
#  Chiapas                    18
#  Chihuahua                  13
#  Ciudad de México           63
#  Coahuila de Zaragoza       25
#  Colima                      0
#  Durango                    29
#  Estado de México           54
#  Guanajuato                 11
#  Guerrero                    0
#  Hidalgo                    59
#  Jalisco                    22
#  Michoacán                  13
#  Morelos                    31
#  Nayarit                     0
#  Nuevo León                 16
#  Oaxaca                      8
#  Puebla                     90
#  Querétaro                  24
#  Quintana Roo               40
#  San Luis Potosí            27
#  Sinaloa                    11
#  Sonora                      9
#  Tabasco                     5
#  Tamaulipas                 19
#  Tlaxcala                   53
#  Veracruz                   21
#  Yucatán                   100
#  Zacatecas                   0,                       Pozole
#  geoName
#  Aguascalientes            27
#  Baja California           23
#  Baja California Sur       22
#  Campeche                  22
#  Chiapas                   17
#  Chihuahua                 19
#  Ciudad de México          24
#  Coahuila de Zaragoza      20
#  Colima                   100
#  Durango                   18
#  Estado de México          22
#  Guanajuato                24
#  Guerrero                  22
#  Hidalgo                   22
#  Jalisco                   23
#  Michoacán                 20
#  Morelos                   21
#  Nayarit                   22
#  Nuevo León                19
#  Oaxaca                    18
#  Puebla                    21
#  Querétaro                 27
#  Quintana Roo              25
#  San Luis Potosí           40
#  Sinaloa                   20
#  Sonora                    19
#  Tabasco                   24
#  Tamaulipas                21
#  Tlaxcala                  21
#  Veracruz                  23
#  Yucatán                   24
#  Zacatecas                 25,                       Enchiladas
#  geoName
#  Aguascalientes                83
#  Baja California               50
#  Baja California Sur           63
#  Campeche                      39
#  Chiapas                       34
#  Chihuahua                     64
#  Ciudad de México              55
#  Coahuila de Zaragoza          71
#  Colima                        92
#  Durango                       88
#  Estado de México              59
#  Guanajuato                    75
#  Guerrero                      51
#  Hidalgo                       61
#  Jalisco                       73
#  Michoacán                     77
#  Morelos                       48
#  Nayarit                       68
#  Nuevo León                    89
#  Oaxaca                        39
#  Puebla                        46
#  Querétaro                     75
#  Quintana Roo                  56
#  San Luis Potosí               93
#  Sinaloa                       79
#  Sonora                        53
#  Tabasco                       61
#  Tamaulipas                    56
#  Tlaxcala                      37
#  Veracruz                      52
#  Yucatán                       41
#  Zacatecas                    100,                       Chilaquiles
#  geoName
#  Aguascalientes                 38
#  Baja California                67
#  Baja California Sur            88
#  Campeche                       65
#  Chiapas                        50
#  Chihuahua                      32
#  Ciudad de México               58
#  Coahuila de Zaragoza           61
#  Colima                         61
#  Durango                        60
#  Estado de México               41
#  Guanajuato                     38
#  Guerrero                       27
#  Hidalgo                        39
#  Jalisco                        96
#  Michoacán                      41
#  Morelos                        33
#  Nayarit                        63
#  Nuevo León                     80
#  Oaxaca                         35
#  Puebla                         43
#  Querétaro                      58
#  Quintana Roo                  100
#  San Luis Potosí                44
#  Sinaloa                        55
#  Sonora                         47
#  Tabasco                        68
#  Tamaulipas                     37
#  Tlaxcala                       29
#  Veracruz                       37
#  Yucatán                        73
#  Zacatecas                      35]

# %% [markdown]
# ### Filtering by state

# %%
def getTrends(google_trends, state):
    requests = google_trends[0].join(google_trends[1:]).T
    return requests[state].sort_values(ascending=False)

# %%
trends =  getTrends(google_trends, 'Tamaulipas')
trends
# Out:
# Tamales             100
# Pollo                89
# Gorditas             82
# Carne                81
# Chicharrón           75
# Menudo               70
# Asada                66
# Pizza                62
# Hamburguesas         59
# Empanadas            59
# Pescado              56
# Enchiladas           56
# Desayunos            50
# Costillas            50
# Hot Dogs             45
# Pastor               44
# Mariscos             44
# Carnitas             44
# Cochinita            41
# Chilaquiles          37
# Arrachera            36
# Barbacoa             35
# China                32
# Antojitos            29
# Tacos                28
# Mondongo             27
# Huaraches            22
# Tortas               21
# Pozole               21
# Carnero              19
# Parrilla             18
# Memelas              18
# Panuchos             12
# Birria               12
# Sushi                 8
# Yucateca              2
# Doraditas             0
# Tabasqueña            0
# Rosticería            0
# Baguettes             0
# Cocina Económica      0
# Name: Tamaulipas, dtype: int64

# %% [markdown]
# ## Adding demand to the main dataframe df

# %%
df['GoogleTrend'] = trends
df
# Out:
#                   InegiCount  GoogleTrend
# Index
# Cocina Económica         185            0
# Antojitos                156           29
# Pizza                     31           62
# Hamburguesas              31           59
# Hot Dogs                  23           45
# Sushi                      2            8
# Tamales                   39          100
# Mariscos                  45           44
# Pescado                   11           56
# Tacos                    344           28
# Carne                      0           81
# Asada                     69           66
# Panuchos                   0           12
# Cochinita                  9           41
# Pollo                    113           89
# Desayunos                  2           50
# Tortas                   252           21
# Mondongo                   1           27
# Menudo                     0           70
# Memelas                    0           18
# Empanadas                  9           59
# Chicharrón                 1           75
# Gorditas                 111           82
# Costillas                  1           50
# Carnitas                  38           44
# Doraditas                  0            0
# Baguettes                  5            0
# Parrilla                  11           18
# Huaraches                  1           22
# Rosticería                 5            0
# China                      0           32
# Yucateca                   3            2
# Tabasqueña                 0            0
# Arrachera                  2           36
# Pastor                    10           44
# Birria                     0           12
# Barbacoa                  26           35
# Carnero                    0           19
# Pozole                     0           21
# Enchiladas                 1           56
# Chilaquiles                1           37

# %% [markdown]
# ## Interest over time

# %%
def getGoogleIOT():
    pytrends = TrendReq(hl='es-MX', tz=360)
    iot = {}
    for comida in foods:
        print(comida)
        pytrends.build_payload([comida], cat=71, geo='MX', gprop='')
        iot[comida] = pytrends.interest_over_time()
        
    return iot

# %%
iot = getGoogleIOT()
iot
# Out:
# Cocina Económica
# Antojitos
# Pizza
# Hamburguesas
# Hot Dogs
# Sushi
# Tamales
# Mariscos
# Pescado
# Tacos
# Carne
# Asada
# Panuchos
# Cochinita
# Pollo
# Desayunos
# Tortas

# %%
import matplotlib.pyplot as plt

x = [i+1 for i in range(len(iot['Tortas']['Tortas']))]

#for food in foods:
plt.figure(figsize=(16,4))

plt.subplot(1,2,1)
plt.title('Tortas')
plt.plot(x, iot['Tortas']['Tortas'].values);

plt.subplot(1,2,2)
plt.title('Tortas')
plt.plot(x, iot['Tacos']['Tacos'].values);

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

def getTrendSlope(foods, iot):
    x = [i+1 for i in range(len(iot['Desayunos']['Desayunos']))]
    linreg = LinearRegression()

    slope = {}
    for food in foods:
        linreg.fit(np.array(x).reshape(-1,1), iot[food][food].values)
        slope[food] = linreg.coef_[0]

    return slope

# %%
slope = getTrendSlope(foods, iot)
slope

# %%
plt.figure(figsize=(16,4))

plt.subplot(1,2,1)
plt.plot(x, iot['Tortas']['Tortas'].values);
plt.title('Tortas')

print('Tortas slope:',slope['Tortas'])
yslope = [50.3 + i*slope['Tortas'] for i in range(len(iot['Tortas']['Tortas']))]
plt.plot(x, yslope);

plt.subplot(1,2,2)
plt.plot(x, iot['Tacos']['Tacos'].values);
plt.title('Tacos')

print('Tacos slope:',slope['Tacos'])
yslope = [38.145240200412616 + i*slope['Tacos'] for i in range(len(iot['Tacos']['Tacos']))]
plt.plot(x, yslope);

# %% [markdown]
# ## Adding trending to the main dataframe df

# %%
def addSlopeToDf(df):
    df['slope'] = ''
    for key in slope:
        df['slope'].loc[key] = slope[key]
    df.slope = df.slope.astype('float64')
    
    return df

# %%
df = addSlopeToDf(df)
df.head()

# %% [markdown]
# # User location geocode with GeoPy

# %%
from geopy.geocoders import Nominatim
#user_input = input('Introduce lugar:')

def userLocationGeocoding(string):
    geolocator = Nominatim(user_agent="food-business-recommender")
    return geolocator.geocode(string)

# %% [markdown]
# ### As use case we are selecting 'unidad modelo' as the neiborghood

# %%
location = userLocationGeocoding('unidad modelo tampico tamaulipas')
location

# %% [markdown]
# # Yelp
# In this section we are getting the satisfaction.
#
# We are using the endpoint https://api.yelp.com/v3/businesses/search from the Yelp API https://www.yelp.com/developers

# %%
import requests
from bs4 import BeautifulSoup as bs
import json

# %% [markdown]
# ## Searching for food business on the user location

# %%
def searchYelp(foods, location):
    api_key = os.getenv("YELP_API_KEY")
    endpoint = 'https://api.yelp.com/v3/businesses/search?'
    
    yelp_search = []
    for comida in foods:
        term = 'term={}&'.format(comida)
        print(term)
        
        latitude = 'latitude='+str(location.latitude)+'&'
        longitude = 'longitude='+str(location.longitude)+'&'
        locale = 'locale=es_MX&'
        radius = 'radius=3000&'
        limit = 'limit=50' 
        
        res = requests.get(endpoint+term+latitude+longitude+locale+radius+limit, headers={'Authorization':'Bearer '+api_key})
        
        soup = bs(res.content)
        yelp_json = json.loads(soup.findAll('p')[0].text)
        
        ydf = pd.DataFrame(yelp_json['businesses'])
        ydf['tipo'] = comida
        yelp_search.append(ydf)

    return yelp_search

# %%
yelp_search = searchYelp(foods, location)
yelp_search

# %%
type(yelp_search[0])

# %% [markdown]
# ## Creating a dataframe with the Yelp searches

# %%
def getYelpDf(yelp_search):
    lugares = pd.concat(yelp_search, axis=0, sort=False)
    lugares.reset_index(inplace=True)

    ratings = dict(lugares.tipo.value_counts())
    for comida in foods:
        ratings[comida] = lugares[lugares.tipo == comida]['rating'].mean()

    yf = pd.concat(yelp_search, sort=False)
    yf.drop(columns = ['alias', 'display_phone', 'location', 'id', 'image_url', 'is_closed', 'phone', 'transactions', 'url'], inplace=True)
    yf.reset_index(inplace=True)
    return yf

# %%
yf = getYelpDf(yelp_search)
yf

# %% [markdown]
# ## Adding satisfaction to the main dataframe df

# %%
df['YelpRating'] = yf.groupby('tipo').mean().rating
df

# %% [markdown]
# # Score

# %%
df.head()

# %% [markdown]
# ## Changing column names in order to understand them better

# %%
df.rename(columns={'InegiCount':'Offer', 'GoogleTrend':'Demand', 'slope':'Trending', 'YelpRating':'Satisfaction'}, inplace=True)
df.head()

# %%
for column in df.columns:
    df[column] = df[column]/df[column].max()
    
df.head()

# %% [markdown]
# ## Calculating score

# %%
def calculateScore(df):
    #df['score'] = df.Demand/100 + df.Trending/df.Trending.max() - df.Satisfaction/5 - df.Offer/df.Offer.max()
    df['score'] = df.Demand + df.Trending - df.Satisfaction - df.Offer
    return df.sort_values(by='score', ascending=False).head(3)

# %%
df = calculateScore(df)
df

# %% [markdown]
# # Yelp top competitors by location

# %%
from pandas.io.json import json_normalize

# %% [markdown]
# ## Extracting coordinates from the Yelp dataframe

# %%
def flatLatLong(yf):
    yf[['latitude', 'longitude']] = json_normalize(yf.coordinates)
    return yf

# %%
yf = flatLatLong(yf)
yf

# %% [markdown]
# ## Looking for the top competitors

# %%
def getTopYf(yf):
    top_yf = pd.DataFrame(columns = yf.columns)
    top_types = df.sort_values(by='score', ascending=False).head().index
    
    for top in top_types:
        top_yf = pd.concat([top_yf, yf[yf.tipo==top].sort_values(by='rating', ascending=False).head(10)])

    return top_yf

# %%
top_yf = getTopYf(yf)
top_yf

# %%
def getTopCompetitors(top_yf):
    top_yf_list = []
    for tipo in top_yf.tipo.unique():
        toadd = {'tipo': tipo}
        for index in top_yf[top_yf.tipo==tipo].index:
            toadd['name'] = top_yf.name.loc[index]
            toadd['coords'] = [top_yf.latitude.loc[index], top_yf.longitude.loc[index]]
            top_yf_list.append(toadd)

    return top_yf_list

# %%
getTopCompetitors(top_yf)

# %% [markdown]
# # Foursquare

# %%
import foursquare

# %%
def getFsResults(top_yf):
    client_id = os.getenv("FS_CLIENT_ID")
    client_secret = os.getenv("FS_CLIENT_SECRET")
    client = foursquare.Foursquare(client_id=client_id, client_secret=client_secret)

    fs_results = {}
    comida = top_yf.tipo.unique()[0]
    #for comida in top_yf.tipo.unique():
    #    print(comida)
    fs_results[comida] = client.venues.search(params={'query': comida, 'intent':'checkin', 'll': str(location.latitude)+', '+str(location.longitude), 'radius':3000, 'limit':10})

    return fs_results

# %%
def getFsResults(top_yf):
    client_id = os.getenv("FS_CLIENT_ID")
    client_secret = os.getenv("FS_CLIENT_SECRET")
    client = foursquare.Foursquare(client_id=client_id, client_secret=client_secret)

    fs_results = []
    comida = top_yf.tipo.unique()[0]
    #for comida in top_yf.tipo.unique():
    #    print(comida)
    fs_results.append(client.venues.search(params={'query': comida, 'intent':'checkin', 'll': str(location.latitude)+', '+str(location.longitude), 'radius':3000, 'limit':10}))

    return fs_results[0]['venues']

# %%
fs_results = getFsResults(top_yf)
fs_results

# %%
'''
def getFsLocs(fs_results):
    fs_locs = {}
    for result in fs_results:
        result_locs = []
        for i in range(len(fs_results[result]['venues'])):
            loc = {}
            loc[fs_results[result]['venues'][i]['name']] = []
            loc[fs_results[result]['venues'][i]['name']].append(fs_results[result]['venues'][i]['location']['lat'])
            loc[fs_results[result]['venues'][i]['name']].append(fs_results[result]['venues'][i]['location']['lng'])
            result_locs.append(loc)
        fs_locs[result] = result_locs

    return fs_locs
'''

# %%
def getFsLocs(fs_results):
    fs_locs = []
    for venue in fs_results:
        fs_locs.append({'name':venue['name'], 'coords':[venue['location']['lat'], venue['location']['lng']]})

    return fs_locs

# %%
fs_locs = getFsLocs(fs_results)
fs_locs

# %% [markdown]
# ## Folium map

# %%
import folium

# %%
top_types = df.sort_values(by='score', ascending=False).head().index

mapa=folium.Map(location=[location.latitude, location.longitude], tiles='openstreetmap',zoom_start=12)

five_colors = ['red', 'orange', 'green']
colors = dict(zip(top_yf.tipo.unique(), five_colors))

folium.Circle([location.latitude, location.longitude], radius=3000, icon=folium.Icon()).add_to(mapa)

for loc in fs_locs:
    folium.Marker(list(loc['coords']), popup='<b>'+ loc['name'] +'</b>', tooltip=top_yf.tipo.unique()[0], icon=folium.Icon(color='gray', icon='info-sign')).add_to(mapa)
    
for i in top_yf.index:
    folium.Marker(list(top_yf.loc[i][['latitude', 'longitude']]), popup='<b>'+top_yf.loc[i]['name']+'</b>', tooltip=top_yf.loc[i]['tipo'], icon=folium.Icon(color=colors[top_yf.loc[i]['tipo']], icon='info-sign')).add_to(mapa)

mapa
